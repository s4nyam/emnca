# %%
# !sudo pip install deflate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python3 EC.py
# Out:
# Generation: 0, Iteration 0, New Best Found Rule set [[(0.329, 0.36, 1), (0.469, 0.69, 1), (0.021, 0.983, 0)], [(0.784, 0.904, 1), (0.265, 0.683, 0), (0.706, 0.739, 1)], [(0.276, 0.946, 1), (0.158, 0.424, 1), (0.495, 0.987, 1)]]
# Generation: 0, Iteration 1, New Best Found Rule set [[(0.594, 0.946, 0), (0.2, 0.606, 1), (0.67, 0.958, 0)], [(0.672, 0.992, 1), (0.056, 0.339, 1), (0.592, 0.826, 0)], [(0.963, 0.98, 0), (0.312, 0.423, 0), (0.037, 0.437, 0)]]
# Generation: 0, Iteration 2, New Best Found Rule set [[(0.594, 0.946, 0), (0.2, 0.606, 1), (0.67, 0.958, 0)], [(0.672, 0.992, 1), (0.056, 0.339, 1), (0.592, 0.826, 0)], [(0.963, 0.98, 0), (0.312, 0.423, 0), (0.037, 0.437, 0)]]
# Generation: 0, Iteration 3, New Best Found Rule set [[(0.331, 0.704, 0), (0.777, 1.0, 0), (0.89, 0.952, 1)], [(0.04, 0.31, 1), (0.939, 0.943, 1), (0.328, 0.331, 1)], [(0.18, 0.491, 1), (0.18, 0.849, 0), (0.016, 0.801, 1)]]
# ...
