# %%
# !sudo pip install deflate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python3 EC.py
# Out:
# Generation: 0, Iteration 0, New Best Found Rule set [[(0.403, 0.968, 0), (0.034, 0.779, 0), (0.283, 0.773, 1)], [(0.757, 0.928, 1), (0.397, 0.398, 0), (0.038, 0.747, 0)], [(0.066, 0.658, 0), (0.273, 0.407, 1), (0.538, 0.86, 1)]]
# Generation: 0, Iteration 1, New Best Found Rule set [[(0.833, 0.848, 0), (0.739, 0.994, 0), (0.738, 0.748, 1)], [(0.177, 0.312, 0), (0.485, 0.559, 0), (0.13, 0.534, 1)], [(0.456, 0.975, 1), (0.284, 0.624, 0), (0.584, 0.682, 1)]]
# Generation: 0, Iteration 2, New Best Found Rule set [[(0.6, 0.822, 1), (0.46, 0.947, 0), (0.57, 0.858, 1)], [(0.728, 0.904, 1), (0.906, 0.93, 0), (0.887, 0.93, 1)], [(0.436, 0.497, 0), (0.55, 0.731, 0), (0.574, 0.66, 0)]]
# Generation: 0, Iteration 3, New Best Found Rule set [[(0.6, 0.822, 1), (0.46, 0.947, 0), (0.57, 0.858, 1)], [(0.728, 0.904, 1), (0.906, 0.93, 0), (0.887, 0.93, 1)], [(0.436, 0.497, 0), (0.55, 0.731, 0), (0.574, 0.66, 0)]]
# ...
