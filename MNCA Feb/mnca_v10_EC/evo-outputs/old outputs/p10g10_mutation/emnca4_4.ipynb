# %%
# !sudo pip install deflate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.2/167.2 KB 13.7 MB/s eta 0:00:00
# ...

# %%
# !python3 EC.py
# Out:
# Generation: 0, Iteration 0, New Best Found Rule set [[(0.393, 0.841, 1), (0.19, 0.465, 0), (0.15, 0.549, 0)], [(0.43, 0.484, 1), (0.745, 0.988, 1), (0.766, 0.815, 1)], [(0.052, 0.293, 0), (0.323, 0.691, 0), (0.462, 0.91, 0)]]
# Generation: 0, Iteration 1, New Best Found Rule set [[(0.241, 0.627, 1), (0.998, 0.999, 1), (0.549, 0.711, 0)], [(0.191, 0.781, 1), (0.596, 0.756, 0), (0.599, 0.851, 0)], [(0.603, 0.708, 1), (0.089, 0.445, 0), (0.794, 0.982, 1)]]
# Generation: 0, Iteration 2, New Best Found Rule set [[(0.291, 0.441, 1), (0.729, 0.754, 0), (0.854, 0.999, 0), (0.28, 0.415, 1), (0.484, 0.56, 0)], [(0.498, 0.597, 0), (0.785, 0.937, 0), (0.802, 0.931, 1)], [(0.729, 0.854, 0), (0.313, 0.837, 1), (0.156, 0.24, 1)]]
# Generation: 0, Iteration 3, New Best Found Rule set [[(0.436, 0.942, 1), (0.021, 0.758, 1), (0.59, 0.763, 1)], [(0.887, 0.894, 1), (0.7, 0.727, 1), (0.587, 0.644, 0)], [(0.363, 0.365, 0), (0.057, 0.563, 1), (0.168, 0.627, 1)]]
# ...
