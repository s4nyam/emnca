# %%
# !sudo pip install deflate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python3 EC.py
# Out:
# Generation: 0, Iteration 0, New Best Found Rule set [[(0.299, 0.331, 0), (0.202, 0.696, 0), (0.05, 0.638, 1)], [(0.534, 0.959, 1), (0.437, 0.956, 1), (0.058, 0.608, 0)], [(0.146, 0.741, 0), (0.714, 0.933, 1), (0.186, 0.48, 0)]]
# Generation: 0, Iteration 1, New Best Found Rule set [[(0.905, 0.944, 0), (0.134, 0.552, 1), (0.269, 0.793, 1)], [(0.019, 0.489, 0), (0.022, 0.648, 0), (0.89, 0.967, 0)], [(0.42, 0.789, 0), (0.792, 0.923, 1), (0.324, 0.907, 1)]]
# Generation: 0, Iteration 2, New Best Found Rule set [[(0.431, 0.461, 0), (0.682, 0.869, 1), (0.019, 0.38, 1)], [(0.361, 0.71, 0), (0.218, 0.428, 0), (0.173, 0.502, 1)], [(0.531, 0.593, 1), (0.578, 0.629, 1), (0.389, 0.54, 1)]]
# Generation: 0, Iteration 3, New Best Found Rule set [[(0.007, 0.242, 1), (0.153, 0.58, 1), (0.904, 0.959, 0)], [(0.823, 0.835, 1), (0.276, 0.916, 1), (0.284, 0.613, 0)], [(0.095, 0.788, 1), (0.327, 0.736, 1), (0.603, 0.665, 0)]]
# ...
