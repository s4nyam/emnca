# %%
# !sudo pip install deflate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python3 EC.py
# Out:
# Generation: 0, Iteration 0, New Best Found Rule set [[(0.782, 0.953, 1), (0.8, 0.946, 0), (0.957, 0.971, 1)], [(0.817, 0.946, 0), (0.452, 0.694, 0), (0.409, 0.44, 1)], [(0.637, 0.828, 0), (0.021, 0.586, 1), (0.572, 0.753, 1)]]
# Generation: 0, Iteration 1, New Best Found Rule set [[(0.451, 0.511, 0), (0.008, 0.336, 1), (0.735, 0.769, 1)], [(0.839, 0.974, 1), (0.386, 0.667, 1), (0.548, 0.676, 1)], [(0.17, 0.61, 1), (0.012, 0.86, 0), (0.48, 0.823, 1)]]
# Generation: 0, Iteration 2, New Best Found Rule set [[(0.929, 0.981, 0), (0.607, 0.739, 0), (0.784, 0.889, 0)], [(0.727, 0.843, 0), (0.633, 0.901, 1), (0.448, 0.725, 1)], [(0.876, 0.94, 1), (0.753, 0.807, 0), (0.206, 0.254, 0)]]
# Generation: 0, Iteration 3, New Best Found Rule set [[(0.631, 0.826, 1), (0.066, 0.652, 0), (0.067, 0.158, 1)], [(0.518, 0.65, 0), (0.847, 0.925, 0), (0.04, 0.102, 0)], [(0.639, 0.86, 0), (0.666, 0.934, 0), (0.343, 0.536, 0)]]
# ...
