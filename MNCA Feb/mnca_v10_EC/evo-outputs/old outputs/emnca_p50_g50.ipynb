# %%
# !pip install deflate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python3 EC.py
# Out:
# Generation: 0, Iteration 0, New Best Found Rule set [[(0.56, 0.622, 0), (0.886, 0.999, 1), (0.057, 0.635, 0)], [(0.679, 0.999, 1), (0.881, 0.897, 0), (0.629, 0.76, 1)]]
# Generation: 0, Iteration 1, New Best Found Rule set [[(0.449, 0.658, 1), (0.744, 0.898, 1), (0.646, 0.702, 1)], [(0.926, 0.98, 0), (0.384, 0.979, 0), (0.227, 0.516, 0), (0.982, 0.999, 1)]]
# Generation: 0, Iteration 2, New Best Found Rule set [[(0.378, 0.601, 0), (0.419, 0.803, 1), (0.773, 0.959, 1)], [(0.316, 0.653, 1), (0.686, 0.907, 1), (0.064, 0.745, 1), (0.237, 0.792, 1)]]
# Generation: 0, Iteration 3, New Best Found Rule set [[(0.732, 0.84, 1), (0.659, 0.852, 0), (0.102, 0.186, 1)], [(0.17, 0.229, 1), (0.024, 0.824, 0), (0.668, 0.934, 1)]]
# Generation: 0, Iteration 4, New Best Found Rule set [[(0.31, 0.583, 1), (0.104, 0.466, 0), (0.362, 0.821, 1)], [(0.41, 0.604, 0), (0.893, 0.914, 0), (0.447, 0.772, 1), (0.121, 0.533, 1)]]
# ...
