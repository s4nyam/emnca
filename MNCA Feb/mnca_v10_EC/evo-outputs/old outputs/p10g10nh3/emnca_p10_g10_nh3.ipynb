# %%
# !pip install deflate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.2/167.2 KB 4.3 MB/s eta 0:00:00
# ...

# %%
# !python3 EC.py
# Out:
# Generation: 0, Iteration 0, New Best Found Rule set [[(0.869, 0.917, 0), (0.897, 0.913, 1), (0.372, 0.63, 1), (0.11, 0.209, 1), (0.426, 0.474, 0)], [(0.819, 0.859, 0), (0.733, 0.778, 0)], [(0.095, 0.979, 0), (0.462, 0.577, 0), (0.199, 0.828, 1), (0.21, 0.902, 0), (0.815, 0.856, 0)]]
# Generation: 0, Iteration 1, New Best Found Rule set [[(0.713, 0.884, 1), (0.834, 0.948, 1), (0.425, 0.443, 1)], [(0.676, 0.831, 0), (0.14, 0.342, 0), (0.405, 0.931, 0), (0.54, 0.625, 0), (0.433, 0.691, 1)], [(0.187, 0.532, 1), (0.673, 0.98, 1), (0.74, 0.77, 0)]]
# Generation: 0, Iteration 2, New Best Found Rule set [[(0.941, 0.999, 0), (0.732, 0.957, 1), (0.007, 0.623, 0), (0.892, 0.989, 1)], [(0.465, 0.475, 1), (0.582, 0.825, 0), (0.213, 0.291, 0), (0.478, 0.569, 0)], [(0.054, 0.416, 1), (0.293, 0.572, 1), (0.501, 0.729, 1)]]
# ...
