# %%
# !sudo pip install deflate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# OVERALL_PROBABILITY_ATLEAST = 3
# !python3 EC.py
# Out:
# Generation: 0, Iteration 0, New Best Found Rule set [[(0.496, 0.987, 0), (0.321, 0.429, 1), (0.784, 0.796, 1)], [(0.41, 0.657, 0), (0.715, 0.854, 0), (0.226, 0.903, 1)], [(0.128, 0.382, 0), (0.396, 0.89, 0), (0.846, 0.961, 0)]] Deflate 105699
# Generation: 0, Iteration 1, New Best Found Rule set [[(0.759, 0.929, 0), (0.202, 0.641, 0)], [(0.142, 0.519, 0), (0.143, 0.404, 1), (0.568, 0.584, 1), (0.22, 0.343, 0)], [(0.286, 0.842, 1), (0.587, 0.765, 0), (0.108, 0.831, 0)]] Deflate 126558
# Generation: 0, Iteration 2, New Best Found Rule set [[(0.493, 0.747, 1), (0.002, 0.848, 0), (0.113, 0.908, 0)], [(0.113, 0.742, 0), (0.377, 0.838, 1)], [(0.157, 0.702, 1), (0.206, 0.723, 1)]] Deflate 102716
# Generation: 0, Iteration 3, New Best Found Rule set [[(0.759, 0.929, 0), (0.202, 0.641, 0), (0.807, 0.989, 0)], [(0.142, 0.519, 0), (0.143, 0.404, 1), (0.568, 0.584, 1), (0.22, 0.343, 0)], [(0.286, 0.842, 1), (0.587, 0.765, 0), (0.108, 0.831, 0)]] Deflate 126558
# ...
