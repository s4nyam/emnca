# %%
# !sudo pip install deflate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.2/167.2 KB 7.7 MB/s eta 0:00:00
# ...

# %%
# OVERALL_PROBABILITY_ATLEAST = 1
# !python3 EC.py
# Out:
# Generation: 0, Iteration 0, New Best Found Rule set [[(0.659, 0.809, 0), (0.737, 0.775, 1), (0.957, 0.958, 0)], [(0.597, 0.966, 1), (0.21, 0.611, 0), (0.153, 0.437, 0)], [(0.755, 0.919, 1), (0.197, 0.701, 0), (0.373, 0.742, 1)]] Deflate 78980
# Generation: 0, Iteration 1, New Best Found Rule set [[(0.862, 0.878, 0), (0.796, 0.837, 1), (0.672, 0.868, 1), (0.185, 0.39, 1)], [(0.371, 0.706, 1), (0.375, 0.667, 0)], [(0.462, 0.759, 1), (0.561, 0.849, 1), (0.619, 0.795, 0)]] Deflate 64685
# Generation: 0, Iteration 2, New Best Found Rule set [[(0.73, 0.965, 1), (0.994, 0.995, 1), (0.556, 0.805, 0)], [(0.523, 0.696, 0), (0.519, 0.951, 0), (0.161, 0.675, 1)], [(0.879, 0.906, 1), (0.381, 0.823, 1), (0.716, 0.938, 1)]] Deflate 103531
# Generation: 0, Iteration 3, New Best Found Rule set [[(0.985, 0.996, 0), (0.655, 0.907, 0)], [(0.022, 0.613, 0), (0.276, 0.866, 0), (0.326, 0.621, 1)], [(0.941, 0.997, 0), (0.418, 0.743, 0), (0.124, 0.421, 1)]] Deflate 113490
# ...
