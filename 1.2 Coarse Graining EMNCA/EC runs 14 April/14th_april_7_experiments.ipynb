# %%
# !wget https://dl3.pushbulletusercontent.com/8kKFav2tUQchF1x3DV2uSM4hGvwOXE76/EC%20runs%2014%20April.zip
# Out:
# --2023-04-14 14:03:47--  https://dl3.pushbulletusercontent.com/8kKFav2tUQchF1x3DV2uSM4hGvwOXE76/EC%20runs%2014%20April.zip
# Resolving dl3.pushbulletusercontent.com (dl3.pushbulletusercontent.com)... 35.208.62.122
# Connecting to dl3.pushbulletusercontent.com (dl3.pushbulletusercontent.com)|35.208.62.122|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2114968 (2.0M) [application/zip]
# Saving to: ‘EC runs 14 April.zip’
#
# EC runs 14 April.zi 100%[===================>]   2.02M  7.26MB/s    in 0.3s
#
# 2023-04-14 14:03:48 (7.26 MB/s) - ‘EC runs 14 April.zip’ saved [2114968/2114968]

# %%
# !unzip -q *.zip

# %%
# !rm -rf __MACOSX

# %%
# !rm -rf sample_data

# %%
# !rm *.zip

# %%
import os
os.rename("EC runs 14 April","plot_data")

# %%
# !rm plot_data/*/*.ipynb

# %% [markdown]
# # Experiment 1

# %%
import pandas as pd

evocg_history = pd.read_csv("/content/plot_data/exp1outs/evo-cg-1681423289.7399168.csv")
evohd_history = pd.read_csv("/content/plot_data/exp1outs/evo-hd-1681423428.984006.csv")
evohdcg_history = pd.read_csv("/content/plot_data/exp1outs/evo-hdcg-1681422999.846791.csv")

# %%
# Plotting HD data from experiments
import matplotlib.pyplot as plt
plt.plot(evocg_history.evocg_hd_history, label="HD data from Evolution running on CG")
plt.plot(evohd_history.evohd_hd_history,label="HD data from Evolution running on HD")
plt.plot(evohdcg_history.evohdcg_hd_history,label="HD data from Evolution running on HDCG")
plt.legend()
plt.show()

# %%
# Plotting CG data from experiments
import matplotlib.pyplot as plt
plt.plot(evocg_history.evocg_cg_history, label="CG data from Evolution running on CG")
plt.plot(evohd_history.evohd_cg_history,label="CG data from Evolution running on HD")
plt.plot(evohdcg_history.evohdcg_cg_history,label="CG data from Evolution running on HDCG")
plt.legend()
plt.show()

# %%
# Plotting HD data from experiments
import matplotlib.pyplot as plt
plt.plot(evocg_history.evocg_hdcg_history, label="HDCG data from Evolution running on CG")
plt.plot(evohd_history.evohd_hdcg_history,label="HDCG data from Evolution running on HD")
plt.plot(evohdcg_history.evohdcg_hdcg_history,label="HDCG data from Evolution running on HDCG")
plt.legend()
plt.show()

# %% [markdown]
# # Experiment 2

# %%
import pandas as pd

evocg_history = pd.read_csv("/content/plot_data/exp2outs/evo-cg-1681423561.25503.csv")
evohd_history = pd.read_csv("/content/plot_data/exp2outs/evo-hd-1681423444.6756673.csv")
evohdcg_history = pd.read_csv("/content/plot_data/exp2outs/evo-hdcg-1681423458.3291116.csv")

# %%
# Plotting HD data from experiments
import matplotlib.pyplot as plt
plt.plot(evocg_history.evocg_hd_history, label="HD data from Evolution running on CG")
plt.plot(evohd_history.evohd_hd_history,label="HD data from Evolution running on HD")
plt.plot(evohdcg_history.evohdcg_hd_history,label="HD data from Evolution running on HDCG")
plt.legend()
plt.show()

# %%
# Plotting CG data from experiments
import matplotlib.pyplot as plt
plt.plot(evocg_history.evocg_cg_history, label="CG data from Evolution running on CG")
plt.plot(evohd_history.evohd_cg_history,label="CG data from Evolution running on HD")
plt.plot(evohdcg_history.evohdcg_cg_history,label="CG data from Evolution running on HDCG")
plt.legend()
plt.show()

# %%
# Plotting HD data from experiments
import matplotlib.pyplot as plt
plt.plot(evocg_history.evocg_hdcg_history, label="HDCG data from Evolution running on CG")
plt.plot(evohd_history.evohd_hdcg_history,label="HDCG data from Evolution running on HD")
plt.plot(evohdcg_history.evohdcg_hdcg_history,label="HDCG data from Evolution running on HDCG")
plt.legend()
plt.show()

# %% [markdown]
# # Experiment 3

# %%
import pandas as pd

evocg_history = pd.read_csv("/content/plot_data/exp3outs/evo-cg-1681425092.717967.csv")
evohd_history = pd.read_csv("/content/plot_data/exp3outs/evo-hd-1681423788.8667438.csv")
evohdcg_history = pd.read_csv("/content/plot_data/exp3outs/evo-hdcg-1681423704.7307758.csv")

# %%
# Plotting HD data from experiments
import matplotlib.pyplot as plt
plt.plot(evocg_history.evocg_hd_history, label="HD data from Evolution running on CG")
plt.plot(evohd_history.evohd_hd_history,label="HD data from Evolution running on HD")
plt.plot(evohdcg_history.evohdcg_hd_history,label="HD data from Evolution running on HDCG")
plt.legend()
plt.show()

# %%
# Plotting CG data from experiments
import matplotlib.pyplot as plt
plt.plot(evocg_history.evocg_cg_history, label="CG data from Evolution running on CG")
plt.plot(evohd_history.evohd_cg_history,label="CG data from Evolution running on HD")
plt.plot(evohdcg_history.evohdcg_cg_history,label="CG data from Evolution running on HDCG")
plt.legend()
plt.show()

# %%
# Plotting HD data from experiments
import matplotlib.pyplot as plt
plt.plot(evocg_history.evocg_hdcg_history, label="HDCG data from Evolution running on CG")
plt.plot(evohd_history.evohd_hdcg_history,label="HDCG data from Evolution running on HD")
plt.plot(evohdcg_history.evohdcg_hdcg_history,label="HDCG data from Evolution running on HDCG")
plt.legend()
plt.show()

# %% [markdown]
# # Experiment 4

# %%
import pandas as pd

evocg_history = pd.read_csv("/content/plot_data/exp4outs/evo-cg-1681425847.2133236.csv")
evohd_history = pd.read_csv("/content/plot_data/exp4outs/evo-hd-1681424368.1586087.csv")
evohdcg_history = pd.read_csv("/content/plot_data/exp4outs/evo-hdcg-1681423848.3850465.csv")

# %%
# Plotting HD data from experiments
import matplotlib.pyplot as plt
plt.plot(evocg_history.evocg_hd_history, label="HD data from Evolution running on CG")
plt.plot(evohd_history.evohd_hd_history,label="HD data from Evolution running on HD")
plt.plot(evohdcg_history.evohdcg_hd_history,label="HD data from Evolution running on HDCG")
plt.legend()
plt.show()

# %%
# Plotting CG data from experiments
import matplotlib.pyplot as plt
plt.plot(evocg_history.evocg_cg_history, label="CG data from Evolution running on CG")
plt.plot(evohd_history.evohd_cg_history,label="CG data from Evolution running on HD")
plt.plot(evohdcg_history.evohdcg_cg_history,label="CG data from Evolution running on HDCG")
plt.legend()
plt.show()

# %%
# Plotting HD data from experiments
import matplotlib.pyplot as plt
plt.plot(evocg_history.evocg_hdcg_history, label="HDCG data from Evolution running on CG")
plt.plot(evohd_history.evohd_hdcg_history,label="HDCG data from Evolution running on HD")
plt.plot(evohdcg_history.evohdcg_hdcg_history,label="HDCG data from Evolution running on HDCG")
plt.legend()
plt.show()

# %% [markdown]
# # Experiment 5

# %%
import pandas as pd

evocg_history = pd.read_csv("/content/plot_data/exp5outs/evo-cg-1681428838.2339618.csv")
evohd_history = pd.read_csv("/content/plot_data/exp5outs/evo-hd-1681424703.8896172.csv")
evohdcg_history = pd.read_csv("/content/plot_data/exp5outs/evo-hdcg-1681424244.3644228.csv")

# %%
# Plotting HD data from experiments
import matplotlib.pyplot as plt
plt.plot(evocg_history.evocg_hd_history, label="HD data from Evolution running on CG")
plt.plot(evohd_history.evohd_hd_history,label="HD data from Evolution running on HD")
plt.plot(evohdcg_history.evohdcg_hd_history,label="HD data from Evolution running on HDCG")
plt.legend()
plt.show()

# %%
# Plotting CG data from experiments
import matplotlib.pyplot as plt
plt.plot(evocg_history.evocg_cg_history, label="CG data from Evolution running on CG")
plt.plot(evohd_history.evohd_cg_history,label="CG data from Evolution running on HD")
plt.plot(evohdcg_history.evohdcg_cg_history,label="CG data from Evolution running on HDCG")
plt.legend()
plt.show()

# %%
# Plotting HD data from experiments
import matplotlib.pyplot as plt
plt.plot(evocg_history.evocg_hdcg_history, label="HDCG data from Evolution running on CG")
plt.plot(evohd_history.evohd_hdcg_history,label="HDCG data from Evolution running on HD")
plt.plot(evohdcg_history.evohdcg_hdcg_history,label="HDCG data from Evolution running on HDCG")
plt.legend()
plt.show()

# %% [markdown]
# # Experiment 6

# %%
import pandas as pd

evocg_history = pd.read_csv("/content/plot_data/exp6outs/evo-cg-1681431659.0048115.csv")
evohd_history = pd.read_csv("/content/plot_data/exp6outs/evo-hd-1681432670.646527.csv")
evohdcg_history = pd.read_csv("/content/plot_data/exp6outs/evo-hdcg-1681425004.5802636.csv")

# %%
# Plotting HD data from experiments
import matplotlib.pyplot as plt
plt.plot(evocg_history.evocg_hd_history, label="HD data from Evolution running on CG")
plt.plot(evohd_history.evohd_hd_history,label="HD data from Evolution running on HD")
plt.plot(evohdcg_history.evohdcg_hd_history,label="HD data from Evolution running on HDCG")
plt.legend()
plt.show()

# %%
# Plotting CG data from experiments
import matplotlib.pyplot as plt
plt.plot(evocg_history.evocg_cg_history, label="CG data from Evolution running on CG")
plt.plot(evohd_history.evohd_cg_history,label="CG data from Evolution running on HD")
plt.plot(evohdcg_history.evohdcg_cg_history,label="CG data from Evolution running on HDCG")
plt.legend()
plt.show()

# %%
# Plotting HD data from experiments
import matplotlib.pyplot as plt
plt.plot(evocg_history.evocg_hdcg_history, label="HDCG data from Evolution running on CG")
plt.plot(evohd_history.evohd_hdcg_history,label="HDCG data from Evolution running on HD")
plt.plot(evohdcg_history.evohdcg_hdcg_history,label="HDCG data from Evolution running on HDCG")
plt.legend()
plt.show()

# %% [markdown]
# # Experiment 7

# %%
import pandas as pd

evocg_history = pd.read_csv("/content/plot_data/exp7outs/evo-cg-1681477296.8466885.csv")
evohd_history = pd.read_csv("/content/plot_data/exp7outs/evo-hd-1681473268.5773432.csv")
evohdcg_history = pd.read_csv("/content/plot_data/exp7outs/evo-hdcg-1681427837.6331134.csv")

# %%
# Plotting HD data from experiments
import matplotlib.pyplot as plt
plt.plot(evocg_history.evocg_hd_history, label="HD data from Evolution running on CG")
plt.plot(evohd_history.evohd_hd_history,label="HD data from Evolution running on HD")
plt.plot(evohdcg_history.evohdcg_hd_history,label="HD data from Evolution running on HDCG")
plt.legend()
plt.show()

# %%
# Plotting CG data from experiments
import matplotlib.pyplot as plt
plt.plot(evocg_history.evocg_cg_history, label="CG data from Evolution running on CG")
plt.plot(evohd_history.evohd_cg_history,label="CG data from Evolution running on HD")
plt.plot(evohdcg_history.evohdcg_cg_history,label="CG data from Evolution running on HDCG")
plt.legend()
plt.show()

# %%
# Plotting HD data from experiments
import matplotlib.pyplot as plt
plt.plot(evocg_history.evocg_hdcg_history, label="HDCG data from Evolution running on CG")
plt.plot(evohd_history.evohd_hdcg_history,label="HDCG data from Evolution running on HD")
plt.plot(evohdcg_history.evohdcg_hdcg_history,label="HDCG data from Evolution running on HDCG")
plt.legend()
plt.show()
