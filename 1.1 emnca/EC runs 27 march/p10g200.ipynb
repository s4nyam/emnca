# %%
# !pip install deflate
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting deflate
#   Downloading deflate-0.3.0.tar.gz (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.5/149.5 kB 5.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: deflate
#   Building wheel for deflate (setup.py) ... done
#   Created wheel for deflate: filename=deflate-0.3.0-cp310-cp310-linux_x86_64.whl size=35650 sha256=5c774a49cb670218b2172578a8bce43c7cf12d3483cbee602bdf13476d307a41
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/e0/57/fb/688c5edb95442e3bdb3715d1c69d932d3fc80548e526827146
# Successfully built deflate
# Installing collected packages: deflate
# Successfully installed deflate-0.3.0

# %%
# !wget https://dl3.pushbulletusercontent.com/TvHPfXu81gCythGyuHcvDrvgoNgD26H5/code.zip
# !unzip code.zip
# !rm EC.py
# !rm mnca.py
# Out:
# --2023-03-26 00:53:25--  https://dl3.pushbulletusercontent.com/TvHPfXu81gCythGyuHcvDrvgoNgD26H5/code.zip
# Resolving dl3.pushbulletusercontent.com (dl3.pushbulletusercontent.com)... 35.208.62.122
# Connecting to dl3.pushbulletusercontent.com (dl3.pushbulletusercontent.com)|35.208.62.122|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4933 (4.8K) [application/x-zip-compressed]
# Saving to: ‘code.zip’
#
# 100%[======================================>] 4,933       --.-K/s   in 0s
#
# 2023-03-26 00:53:25 (62.9 MB/s) - ‘code.zip’ saved [4933/4933]
#
# Archive:  code.zip
#   inflating: EC.py
#   inflating: mnca.py
#   inflating: neighborhoods/mask_c1.txt
#   inflating: neighborhoods/mask_c2.txt
#   inflating: neighborhoods/mask_c3.txt

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import deflate
import os
import sys
np.set_printoptions(threshold=sys.maxsize)



def extract_neighborhood_from_file(file_name):
    with open(file_name, "r") as f:
        lines = f.readlines()
        neighborhood = []
        for i, line in enumerate(lines):
            line = line.strip()
            for j, value in enumerate(line.split(" ")):
                if value == "1":
                    neighborhood.append((i-1, j-1))
        return neighborhood



def init_board(width, height, init_state):
    if init_state == "single cell in center":
        board = np.zeros((height, width), dtype=np.int)
        board[height//2, width//2] = 1
    elif init_state == "random cells with some probability":
        p = 0.50 # probability of a cell being alive
        board = np.random.choice([0, 1], size=(height, width), p=[1-p, p])
    elif init_state == "random cells with 2 different states":
        p1 = 0.40 # probability of a cell being state 1
        board = np.random.choice([0, 1, 2], size=(height, width), p=[1-p1, p1/2, p1/2])
    else:
        raise ValueError("Invalid initial state")
    return board

def mnca(range_of_neighborhood_sums):   

    ###############----CONSTANTS----###############
    width = 100
    height = 100
    steps = 50
    init_state = "random cells with some probability"
    # Fixed Neighbohoods
    nh1 = extract_neighborhood_from_file('neighborhoods/mask_c1.txt')
    nh2 = extract_neighborhood_from_file('neighborhoods/mask_c2.txt')
    nh3 = extract_neighborhood_from_file('neighborhoods/mask_c3.txt')

    # neighborhoods = [nh1,nh2,nh3]
    neighborhoods = [nh1,nh2,nh3]
    board_arr = []
    board = init_board(width, height, init_state)
    ###############----CONSTANTS----###############


    for eachstep in range(steps):
        new_board = np.zeros_like(board, dtype=int)
        height, width = board.shape
        for i in range(height):
            for j in range(width):
                next_state = board[i, j]
                for neighborhood, range_of_neighborhood_sum in zip(neighborhoods, range_of_neighborhood_sums):
                    cell_neighborhood = [board[(i + ni + height) % height, (j + nj + width) % width]
                                        for ni, nj in neighborhood]
                    
                    # # use this for sum
                    # neighborhood_sum = sum(cell_neighborhood)
                    
                    # use this for average
                    neighborhood_sum = sum(cell_neighborhood)/len(cell_neighborhood)
                    for lower, upper, new_next_state in range_of_neighborhood_sum:
                        if lower <= neighborhood_sum <= upper:
                            next_state = new_next_state
                new_board[i, j] = next_state
        board[:] = new_board[:]
        board_arr.append(board)
    # Calculate Deflate over that board array
    
    try:
        os.remove("board_arrays.txt")
        # print("Removed Successfully")
    except:
        pass
    with open("board_arrays.txt", "w") as output:
        output.write(str(board_arr))
    
    # filedata = open('board_arrays.txt', "rb").readlines()
    # print(filedata)
    filedata = open('board_arrays.txt', 'r', encoding='utf-8').readlines()
    filedata = ''.join(filedata).encode('utf-8')
    # print(filedata)
    compressed = deflate.gzip_compress(filedata, 8)
    deflate_value = compressed.__sizeof__()
    os.system("rm *.txt")
    return deflate_value



# # Testing handlers

# nh_sum1 = [(0.210,0.220,1),(0.350, 0.500, 0), (0.750, 0.850, 0)]
# nh_sum2 = [(0.100,0.280,0),(0.430, 0.550, 1), (0.120, 0.150, 0)]
# range_of_neighborhood_sums = [nh_sum1,nh_sum2]
# print(mnca(range_of_neighborhood_sums))

# %%
from tempfile import tempdir
import numpy as np
import sys
import random
import matplotlib.pyplot as plt

np.set_printoptions(threshold=sys.maxsize)

# from mnca import mnca

OVERALL_PROBABILITY_ATLEAST = 3 # works as mutation rate
POPULATION_SIZE = 10 #3
GENERATION_SIZE = 200 #3
NUMBER_OF_NEIGHBORHOODS = 3 
NUMBER_OF_BOUNDS_IN_EACH_NEIGHBORHOOD = 3 

total_sum = 3*NUMBER_OF_NEIGHBORHOODS*NUMBER_OF_BOUNDS_IN_EACH_NEIGHBORHOOD



PROBABILITY_OF_INSERTING_A_NEW_RULE = OVERALL_PROBABILITY_ATLEAST/total_sum
PROBABILITY_OF_REMOVING_A_RULE = OVERALL_PROBABILITY_ATLEAST/total_sum
PROBABILITY_OF_CHANGING_A_RULE = OVERALL_PROBABILITY_ATLEAST/total_sum



def generate_random_rule():
    number_of_neighborhood = NUMBER_OF_NEIGHBORHOODS
    number_of_bounds_in_each_neighborhod_average_or_sum = NUMBER_OF_BOUNDS_IN_EACH_NEIGHBORHOOD
    rule = []
    for i in range(number_of_neighborhood):
        ranges = []
        for j in range(number_of_bounds_in_each_neighborhod_average_or_sum):
            lower = round(random.uniform(0, 1),3)
            upper = round(random.uniform(lower, 1),3)
            new_next_state = random.choice([0, 1]) 
            
            ranges.append((lower, upper, new_next_state))
        rule.append(ranges)
    return rule


def init_population():
    population_size = POPULATION_SIZE
    population = []
    for i in range(population_size):
        individual = generate_random_rule()
        population.append(individual)
    return population



def calculate_deflate(genotype):
    deflate = mnca(genotype)
    return deflate



def roulette_wheel_selection(population, fitness_values):

    sorted_population = [x for _,x in sorted(zip(fitness_values,population))]
    sorted_fitness_scores = [_ for _,x in sorted(zip(fitness_values,population))]
    fitness_values = sorted_fitness_scores
    population = sorted_population
    total_fitness = sum(fitness_values)
    probability_values = [fitness/total_fitness for fitness in fitness_values]
    cumulative_probability = np.cumsum(probability_values)
    selected_index = None
    random_value = random.uniform(0, 1)
    for i in range(len(population)):
        if random_value < cumulative_probability[i]:
            selected_index = i
            break

    return population[selected_index], fitness_values[selected_index]



def mutation(rule):
    try:
        number_of_neighborhoods = len(rule)
        for i in range(number_of_neighborhoods):
            number_of_bounds = len(rule[i])
            for j in range(number_of_bounds):
                prob_insert = PROBABILITY_OF_INSERTING_A_NEW_RULE
                prob_remove = PROBABILITY_OF_REMOVING_A_RULE
                prob_change = PROBABILITY_OF_CHANGING_A_RULE
                random_value = random.uniform(0, 1)
                if random_value < prob_insert:
                    new_bound = []
                    lower = round(random.uniform(0, 1),3)
                    upper = round(random.uniform(0, 1),3)
                    new_next_state = random.choice([0, 1])
                    if(lower>upper):
                        temp = lower
                        lower = upper
                        upper = temp
                    new_bound.append((lower, upper, new_next_state))
                    rule[i].extend(new_bound)
                elif prob_insert <= random_value < prob_insert + prob_remove:
                    if(len(rule[i])>1):
                        rule[i].pop(j)
                        number_of_bounds -= 1
                        j -= 1
                    else:
                        mutation(rule[i])
                elif prob_insert + prob_remove <= random_value < prob_insert + prob_remove + prob_change:
                    delta = random.uniform(-0.100,0.100)
                    toss_a_coin = random.uniform(0,1)
                    if(toss_a_coin<0.33):
                        rule[i][j][0] = rule[i][j][0]+delta
                        if(rule[i][j][0] > 1):
                            rule[i][j][0] = 1
                        elif(rule[i][j][0] < 0):
                            rule[i][j][0] = 0
                    elif(0.33<toss_a_coin<0.66):
                        
                        rule[i][j][1] = rule[i][j][1]+delta
                        if(rule[i][j][1] > 1):
                            rule[i][j][1] = 1
                        elif(rule[i][j][1] < 0):
                            rule[i][j][1] = 0
                    else:
                        if(rule[i][j][2] ==0):
                            rule[i][j][2] = 1
                        else:
                            rule[i][j][2] = 0
                    if(rule[i][j][0] > rule[i][j][1]):
                        temp = rule[i][j][0]
                        rule[i][j][0] = rule[i][j][1]
                        rule[i][j][1] = temp
    except:
        pass
    return rule





population = init_population()
generations = GENERATION_SIZE

best_fitness_history = []
average_fitness_history = []
worst_fitness_history = []

for generation in range(generations):
    print("Generation: ", generation)
    
    # Calculate fitness of Individuals
    fitness_values = [calculate_deflate(individual) for individual in population] # Calculate fitness for each individual
    
    
    # Preserving hisotry
    best_individual_index = np.argmax(fitness_values) # elite index
    import copy
    
    best_individual = copy.deepcopy(population[best_individual_index]) # elite chromosome
    best_fitness = fitness_values[best_individual_index] # elite fitness
    print("Best Individual: ") # print best chromo
    print(best_individual)
    print("Best Fitness: ") # print its fitness
    print(best_fitness)
    worst_individual_index = np.argmin(fitness_values) # worst history
    worst_fitness = fitness_values[worst_individual_index] # worst fitness

    avg_fitness = np.mean(fitness_values) # average fitness

    best_fitness_history.append(best_fitness) # preserving history
    average_fitness_history.append(avg_fitness) # preserving history
    worst_fitness_history.append(worst_fitness) # preserving history

    # print("old population: ")
    # print(population)
    # print("fitness values ")
    # print(fitness_values)
    # Preserving elite
    new_population = [best_individual]  # 1elites Elitism
    # print("new population ")
    # print(new_population)

    # Selection of the individuals
    while len(new_population) < POPULATION_SIZE:
        select1, _ = roulette_wheel_selection(population, fitness_values)
        # select2, _ = roulette_wheel_selection(population, fitness_values)
        # First deep copy and then mutation
        deep_copy = copy.deepcopy(select1)
        mutated1 = mutation(deep_copy)
        # mutated2 = mutation(select2)
        # deep_copy = copy.deepcopy(mutated1)
        # new_population.append(deep_copy)
        new_population.append(mutated1)

   
    # print("Brand new pop")
    # print(new_population)
    population = new_population
    # print("population after new population")
    # print(population)
    print("------------------------------------------------------------")
    # print("population in the end: ",population)
# Plot the graph
plt.plot(best_fitness_history, label="Best Fitness")
# plt.plot(average_fitness_history, label="Average Fitness")
# plt.plot(worst_fitness_history, label="Worst Fitness")
plt.xlabel("Generation")
plt.ylabel("Fitness")
plt.title("Genetic Algorithm Fitness over Generations")
plt.legend()
plt.show()
# Out:
# Generation:  0
# Best Individual:
# [[(0.22, 0.317, 1), (0.053, 0.604, 0), (0.725, 0.743, 0)], [(0.868, 0.872, 0), (0.316, 0.62, 1), (0.784, 0.937, 0)], [(0.982, 0.999, 1), (0.947, 0.995, 1), (0.937, 0.994, 0)]]
# Best Fitness:
# 121387
# ------------------------------------------------------------
# Generation:  1
# Best Individual:
# [[(0.22, 0.317, 1), (0.053, 0.604, 0), (0.725, 0.743, 0)], [(0.868, 0.872, 0), (0.316, 0.62, 1), (0.784, 0.937, 0)], [(0.982, 0.999, 1), (0.947, 0.995, 1), (0.937, 0.994, 0)]]
# Best Fitness:
# 122045
# ------------------------------------------------------------
# Generation:  2
# Best Individual:
# [[(0.22, 0.317, 1), (0.053, 0.604, 0), (0.725, 0.743, 0)], [(0.868, 0.872, 0), (0.316, 0.62, 1), (0.784, 0.937, 0)], [(0.982, 0.999, 1), (0.947, 0.995, 1), (0.937, 0.994, 0)]]
# Best Fitness:
# 123843
# ------------------------------------------------------------
# Generation:  3
# Best Individual:
# [[(0.22, 0.317, 1), (0.053, 0.604, 0), (0.538, 0.793, 1)], [(0.868, 0.872, 0), (0.316, 0.62, 1), (0.784, 0.937, 0), (0.104, 0.113, 1), (0.234, 0.55, 1)], [(0.982, 0.999, 1), (0.947, 0.995, 1), (0.937, 0.994, 0)]]
# Best Fitness:
# 123408
# ------------------------------------------------------------
# Generation:  4
# Best Individual:
# [[(0.053, 0.604, 0)], [(0.868, 0.872, 0), (0.316, 0.62, 1), (0.784, 0.937, 0)], [(0.982, 0.999, 1), (0.947, 0.995, 1), (0.937, 0.994, 0)]]
# Best Fitness:
# 119998
# ------------------------------------------------------------
# Generation:  5
# Best Individual:
# [[(0.053, 0.604, 0)], [(0.868, 0.872, 0), (0.316, 0.62, 1), (0.784, 0.937, 0)], [(0.982, 0.999, 1), (0.947, 0.995, 1), (0.937, 0.994, 0)]]
# Best Fitness:
# 120225
# ------------------------------------------------------------
# Generation:  6
# Best Individual:
# [[(0.053, 0.604, 0), (0.725, 0.743, 0), (0.315, 0.467, 0)], [(0.868, 0.872, 0), (0.316, 0.62, 1), (0.784, 0.937, 0)], [(0.982, 0.999, 1), (0.947, 0.995, 1), (0.937, 0.994, 0)]]
# Best Fitness:
# 120239
# ------------------------------------------------------------
# Generation:  7
# Best Individual:
# [[(0.053, 0.604, 0)], [(0.316, 0.62, 1), (0.784, 0.937, 0)], [(0.982, 0.999, 1), (0.947, 0.995, 1), (0.937, 0.994, 0)]]
# Best Fitness:
# 122353
# ------------------------------------------------------------
# Generation:  8
# Best Individual:
# [[(0.053, 0.604, 0)], [(0.316, 0.62, 1), (0.784, 0.937, 0)], [(0.982, 0.999, 1), (0.937, 0.994, 0)]]
# Best Fitness:
# 122034
# ------------------------------------------------------------
# Generation:  9
# Best Individual:
# [[(0.725, 0.743, 0), (0.57, 0.834, 0), (0.062, 0.073, 1), (0.083, 0.323, 0)], [(0.868, 0.872, 0), (0.316, 0.62, 1), (0.521, 0.656, 0)], [(0.982, 0.999, 1), (0.947, 0.995, 1), (0.937, 0.994, 0)]]
# Best Fitness:
# 129498
# ------------------------------------------------------------
# Generation:  10
# Best Individual:
# [[(0.57, 0.834, 0), (0.062, 0.073, 1), (0.083, 0.323, 0), (0.256, 0.828, 0)], [(0.868, 0.872, 0), (0.316, 0.62, 1), (0.521, 0.656, 0), (0.179, 0.274, 1)], [(0.982, 0.999, 1), (0.947, 0.995, 1), (0.937, 0.994, 0)]]
# Best Fitness:
# 131276
# ------------------------------------------------------------
# Generation:  11
# Best Individual:
# [[(0.725, 0.743, 0), (0.57, 0.834, 0), (0.062, 0.073, 1), (0.083, 0.323, 0), (0.752, 0.815, 0)], [(0.868, 0.872, 0), (0.316, 0.62, 1), (0.521, 0.656, 0)], [(0.982, 0.999, 1), (0.947, 0.995, 1), (0.937, 0.994, 0)]]
# Best Fitness:
# 130113
# ------------------------------------------------------------
# Generation:  12
# Best Individual:
# [[(0.57, 0.834, 0), (0.062, 0.073, 1), (0.083, 0.323, 0), (0.256, 0.828, 0)], [(0.868, 0.872, 0), (0.316, 0.62, 1), (0.521, 0.656, 0), (0.179, 0.274, 1)], [(0.982, 0.999, 1), (0.947, 0.995, 1), (0.937, 0.994, 0)]]
# Best Fitness:
# 130145
# ------------------------------------------------------------
# Generation:  13
# Best Individual:
# [[(0.725, 0.743, 0), (0.57, 0.834, 0), (0.062, 0.073, 1), (0.083, 0.323, 0), (0.752, 0.815, 0), (0.643, 0.85, 0)], [(0.868, 0.872, 0), (0.316, 0.62, 1), (0.521, 0.656, 0)], [(0.982, 0.999, 1), (0.947, 0.995, 1), (0.937, 0.994, 0)]]
# Best Fitness:
# 130279
# ------------------------------------------------------------
# Generation:  14
# Best Individual:
# [[(0.57, 0.834, 0), (0.062, 0.073, 1), (0.256, 0.828, 0)], [(0.868, 0.872, 0), (0.316, 0.62, 1), (0.521, 0.656, 0), (0.179, 0.274, 1)], [(0.982, 0.999, 1), (0.947, 0.995, 1), (0.937, 0.994, 0)]]
# Best Fitness:
# 129093
# ------------------------------------------------------------
# Generation:  15
# Best Individual:
# [[(0.725, 0.743, 0), (0.57, 0.834, 0), (0.062, 0.073, 1), (0.083, 0.323, 0), (0.752, 0.815, 0), (0.643, 0.85, 0)], [(0.868, 0.872, 0), (0.316, 0.62, 1), (0.521, 0.656, 0)], [(0.982, 0.999, 1), (0.947, 0.995, 1), (0.937, 0.994, 0)]]
# Best Fitness:
# 131110
# ------------------------------------------------------------
# Generation:  16
# Best Individual:
# [[(0.57, 0.834, 0), (0.062, 0.073, 1), (0.083, 0.323, 0), (0.752, 0.815, 0)], [(0.868, 0.872, 0), (0.316, 0.62, 1), (0.521, 0.656, 0)], [(0.982, 0.999, 1), (0.947, 0.995, 1), (0.937, 0.994, 0)]]
# Best Fitness:
# 128496
# ------------------------------------------------------------
# Generation:  17
# Best Individual:
# [[(0.725, 0.743, 0), (0.57, 0.834, 0), (0.083, 0.323, 0), (0.752, 0.815, 0)], [(0.868, 0.872, 0), (0.316, 0.62, 1), (0.521, 0.656, 0)], [(0.982, 0.999, 1), (0.947, 0.995, 1), (0.937, 0.994, 0)]]
# Best Fitness:
# 129862
# ------------------------------------------------------------
# Generation:  18
# Best Individual:
# [[(0.725, 0.743, 0), (0.083, 0.323, 0), (0.752, 0.815, 0), (0.643, 0.85, 0)], [(0.316, 0.62, 1), (0.521, 0.656, 0)], [(0.947, 0.995, 1), (0.937, 0.994, 0), (0.757, 0.886, 1)]]
# Best Fitness:
# 130243
# ------------------------------------------------------------
# Generation:  19
# Best Individual:
# [[(0.725, 0.743, 0), (0.083, 0.323, 0), (0.752, 0.815, 0)], [(0.868, 0.872, 0), (0.316, 0.62, 1), (0.521, 0.656, 0)], [(0.982, 0.999, 1), (0.947, 0.995, 1)]]
# Best Fitness:
# 129212
# ------------------------------------------------------------
# Generation:  20
# Best Individual:
# [[(0.725, 0.743, 0), (0.083, 0.323, 0), (0.752, 0.815, 0)], [(0.868, 0.872, 0), (0.316, 0.62, 1), (0.521, 0.656, 0)], [(0.982, 0.999, 1), (0.947, 0.995, 1)]]
# Best Fitness:
# 129395
# ------------------------------------------------------------
# Generation:  21
# Best Individual:
# [[(0.725, 0.743, 0), (0.083, 0.323, 0), (0.752, 0.815, 0)], [(0.868, 0.872, 0), (0.316, 0.62, 1), (0.521, 0.656, 0)], [(0.982, 0.999, 1), (0.947, 0.995, 1)]]
# Best Fitness:
# 131385
# ------------------------------------------------------------
# Generation:  22
# Best Individual:
# [[(0.725, 0.743, 0), (0.083, 0.323, 0), (0.752, 0.815, 0)], [(0.868, 0.872, 0), (0.316, 0.62, 1), (0.521, 0.656, 0)], [(0.982, 0.999, 1), (0.947, 0.995, 1)]]
# Best Fitness:
# 131239
# ------------------------------------------------------------
# Generation:  23
# Best Individual:
# [[(0.725, 0.743, 0), (0.083, 0.323, 0), (0.752, 0.815, 0)], [(0.868, 0.872, 0), (0.316, 0.62, 1), (0.521, 0.656, 0)], [(0.982, 0.999, 1), (0.947, 0.995, 1)]]
# Best Fitness:
# 131878
# ------------------------------------------------------------
# Generation:  24
# Best Individual:
# [[(0.725, 0.743, 0), (0.083, 0.323, 0), (0.752, 0.815, 0)], [(0.868, 0.872, 0), (0.316, 0.62, 1), (0.521, 0.656, 0)], [(0.982, 0.999, 1), (0.947, 0.995, 1)]]
# Best Fitness:
# 130702
# ------------------------------------------------------------
# Generation:  25
# Best Individual:
# [[(0.725, 0.743, 0), (0.083, 0.323, 0), (0.752, 0.815, 0)], [(0.868, 0.872, 0), (0.316, 0.62, 1), (0.521, 0.656, 0)], [(0.982, 0.999, 1), (0.947, 0.995, 1)]]
# Best Fitness:
# 131394
# ------------------------------------------------------------
# Generation:  26
# Best Individual:
# [[(0.725, 0.743, 0), (0.083, 0.323, 0), (0.752, 0.815, 0), (0.446, 0.463, 1), (0.729, 0.73, 0)], [(0.868, 0.872, 0), (0.316, 0.62, 1), (0.521, 0.656, 0)], [(0.982, 0.999, 1), (0.947, 0.995, 1)]]
# Best Fitness:
# 134154
# ------------------------------------------------------------
# Generation:  27
# Best Individual:
# [[(0.725, 0.743, 0), (0.083, 0.323, 0), (0.752, 0.815, 0), (0.446, 0.463, 1), (0.729, 0.73, 0)], [(0.868, 0.872, 0), (0.316, 0.62, 1), (0.521, 0.656, 0)], [(0.982, 0.999, 1), (0.947, 0.995, 1)]]
# Best Fitness:
# 131896
# ------------------------------------------------------------
# Generation:  28
# Best Individual:
# [[(0.725, 0.743, 0), (0.752, 0.815, 0), (0.446, 0.463, 1), (0.729, 0.73, 0)], [(0.868, 0.872, 0), (0.521, 0.656, 0)], [(0.982, 0.999, 1), (0.947, 0.995, 1)]]
# Best Fitness:
# 134624
# ------------------------------------------------------------
# Generation:  29
# Best Individual:
# [[(0.725, 0.743, 0), (0.752, 0.815, 0), (0.446, 0.463, 1), (0.729, 0.73, 0)], [(0.868, 0.872, 0), (0.521, 0.656, 0)], [(0.982, 0.999, 1), (0.947, 0.995, 1)]]
# Best Fitness:
# 137348
# ------------------------------------------------------------
# Generation:  30
# Best Individual:
# [[(0.725, 0.743, 0), (0.752, 0.815, 0), (0.446, 0.463, 1), (0.729, 0.73, 0)], [(0.868, 0.872, 0), (0.521, 0.656, 0)], [(0.982, 0.999, 1), (0.947, 0.995, 1)]]
# Best Fitness:
# 137214
# ------------------------------------------------------------
# Generation:  31
# Best Individual:
# [[(0.725, 0.743, 0), (0.752, 0.815, 0), (0.446, 0.463, 1), (0.729, 0.73, 0)], [(0.868, 0.872, 0), (0.521, 0.656, 0)], [(0.982, 0.999, 1), (0.947, 0.995, 1)]]
# Best Fitness:
# 136377
# ------------------------------------------------------------
# Generation:  32
# Best Individual:
# [[(0.725, 0.743, 0), (0.752, 0.815, 0), (0.446, 0.463, 1), (0.729, 0.73, 0)], [(0.868, 0.872, 0)], [(0.982, 0.999, 1), (0.947, 0.995, 1)]]
# Best Fitness:
# 142191
# ------------------------------------------------------------
# Generation:  33
# Best Individual:
# [[(0.725, 0.743, 0), (0.752, 0.815, 0), (0.446, 0.463, 1), (0.729, 0.73, 0)], [(0.868, 0.872, 0)], [(0.982, 0.999, 1), (0.947, 0.995, 1)]]
# Best Fitness:
# 142154
# ------------------------------------------------------------
# Generation:  34
# Best Individual:
# [[(0.725, 0.743, 0), (0.752, 0.815, 0), (0.446, 0.463, 1), (0.729, 0.73, 0)], [(0.868, 0.872, 0)], [(0.982, 0.999, 1), (0.947, 0.995, 1)]]
# Best Fitness:
# 143271
# ------------------------------------------------------------
# Generation:  35
# Best Individual:
# [[(0.752, 0.815, 0), (0.446, 0.463, 1), (0.729, 0.73, 0)], [(0.868, 0.872, 0)], [(0.982, 0.999, 1), (0.947, 0.995, 1)]]
# Best Fitness:
# 143494
# ------------------------------------------------------------
# Generation:  36
# Best Individual:
# [[(0.752, 0.815, 0), (0.446, 0.463, 1), (0.729, 0.73, 0)], [(0.868, 0.872, 0)], [(0.982, 0.999, 1), (0.947, 0.995, 1)]]
# Best Fitness:
# 143909
# ------------------------------------------------------------
# Generation:  37
# Best Individual:
# [[(0.752, 0.815, 0), (0.729, 0.73, 0)], [(0.868, 0.872, 0)], [(0.982, 0.999, 1), (0.947, 0.995, 1)]]
# Best Fitness:
# 143745
# ------------------------------------------------------------
# Generation:  38
# Best Individual:
# [[(0.752, 0.815, 0), (0.446, 0.463, 1), (0.729, 0.73, 0)], [(0.868, 0.872, 0)], [(0.982, 0.999, 1), (0.947, 0.995, 1)]]
# Best Fitness:
# 144374
# ------------------------------------------------------------
# Generation:  39
# Best Individual:
# [[(0.752, 0.815, 0), (0.446, 0.463, 1)], [(0.868, 0.872, 0)], [(0.982, 0.999, 1)]]
# Best Fitness:
# 144057
# ------------------------------------------------------------
# Generation:  40
# Best Individual:
# [[(0.752, 0.815, 0), (0.446, 0.463, 1), (0.729, 0.73, 0)], [(0.868, 0.872, 0)], [(0.982, 0.999, 1), (0.947, 0.995, 1)]]
# Best Fitness:
# 144143
# ------------------------------------------------------------
# Generation:  41
# Best Individual:
# [[(0.446, 0.463, 1), (0.729, 0.73, 0)], [(0.868, 0.872, 0)], [(0.982, 0.999, 1), (0.947, 0.995, 1)]]
# Best Fitness:
# 144290
# ------------------------------------------------------------
# Generation:  42
# Best Individual:
# [[(0.752, 0.815, 0), (0.45, 0.452, 1)], [(0.868, 0.872, 0)], [(0.982, 0.999, 1)]]
# Best Fitness:
# 143538
# ------------------------------------------------------------
# Generation:  43
# Best Individual:
# [[(0.752, 0.815, 0), (0.45, 0.452, 1)], [(0.868, 0.872, 0)], [(0.982, 0.999, 1)]]
# Best Fitness:
# 144265
# ------------------------------------------------------------
# Generation:  44
# Best Individual:
# [[(0.752, 0.815, 0), (0.45, 0.452, 1)], [(0.868, 0.872, 0)], [(0.982, 0.999, 1)]]
# Best Fitness:
# 144132
# ------------------------------------------------------------
# Generation:  45
# Best Individual:
# [[(0.752, 0.815, 0), (0.45, 0.452, 1)], [(0.868, 0.872, 0)], [(0.982, 0.999, 1)]]
# Best Fitness:
# 144576
# ------------------------------------------------------------
# Generation:  46
# Best Individual:
# [[(0.45, 0.452, 1)], [(0.868, 0.872, 0)], [(0.982, 0.999, 1), (0.219, 0.421, 1)]]
# Best Fitness:
# 145232
# ------------------------------------------------------------
# Generation:  47
# Best Individual:
# [[(0.752, 0.815, 0), (0.45, 0.452, 1), (0.007, 0.39, 1)], [(0.868, 0.872, 0)], [(0.982, 0.999, 1)]]
# Best Fitness:
# 145436
# ------------------------------------------------------------
# Generation:  48
# Best Individual:
# [[(0.45, 0.452, 1)], [(0.868, 0.872, 0)], [(0.569, 0.589, 0)]]
# Best Fitness:
# 143998
# ------------------------------------------------------------
# Generation:  49
# Best Individual:
# [[(0.45, 0.452, 1)], [(0.868, 0.872, 0)], [(0.219, 0.421, 1), (0.129, 0.33, 0)]]
# Best Fitness:
# 144329
# ------------------------------------------------------------
# Generation:  50
# Best Individual:
# [[(0.45, 0.452, 1)], [(0.868, 0.872, 0)], [(0.982, 0.999, 1), (0.219, 0.421, 1)]]
# Best Fitness:
# 143809
# ------------------------------------------------------------
# Generation:  51
# Best Individual:
# [[(0.45, 0.452, 1)], [(0.868, 0.872, 0)], [(0.982, 0.999, 1), (0.219, 0.421, 1)]]
# Best Fitness:
# 144008
# ------------------------------------------------------------
# Generation:  52
# Best Individual:
# [[(0.45, 0.452, 1)], [(0.868, 0.872, 0)], [(0.982, 0.999, 1), (0.219, 0.421, 1)]]
# Best Fitness:
# 144523
# ------------------------------------------------------------
# Generation:  53
# Best Individual:
# [[(0.45, 0.452, 1)], [(0.868, 0.872, 0)], [(0.982, 0.999, 1), (0.219, 0.421, 1), (0.084, 0.258, 0)]]
# Best Fitness:
# 144875
# ------------------------------------------------------------
# Generation:  54
# Best Individual:
# [[(0.45, 0.452, 1), (0.629, 0.741, 0)], [(0.868, 0.872, 0)], [(0.982, 0.999, 1), (0.547, 0.984, 0)]]
# Best Fitness:
# 143841
# ------------------------------------------------------------
# Generation:  55
# Best Individual:
# [[(0.45, 0.452, 1)], [(0.868, 0.872, 0)], [(0.982, 0.999, 1), (0.219, 0.421, 1), (0.084, 0.258, 0), (0.72, 0.786, 0)]]
# Best Fitness:
# 144471
# ------------------------------------------------------------
# Generation:  56
# Best Individual:
# [[(0.45, 0.452, 1)], [(0.868, 0.872, 0), (0.024, 0.203, 1)], [(0.982, 0.999, 1), (0.219, 0.421, 1), (0.71, 0.927, 1)]]
# Best Fitness:
# 145164
# ------------------------------------------------------------
# Generation:  57
# Best Individual:
# [[(0.45, 0.452, 1), (0.629, 0.741, 0), (0.851, 0.99, 1)], [(0.868, 0.872, 0)], [(0.982, 0.999, 1), (0.547, 0.984, 0)]]
# Best Fitness:
# 145096
# ------------------------------------------------------------
# Generation:  58
# Best Individual:
# [[(0.45, 0.452, 1)], [(0.868, 0.872, 0), (0.024, 0.203, 1)], [(0.982, 0.999, 1), (0.219, 0.421, 1), (0.71, 0.927, 1)]]
# Best Fitness:
# 144155
# ------------------------------------------------------------
# Generation:  59
# Best Individual:
# [[(0.629, 0.741, 0), (0.055, 0.27, 1)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 144514
# ------------------------------------------------------------
# Generation:  60
# Best Individual:
# [[(0.055, 0.27, 1)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 144597
# ------------------------------------------------------------
# Generation:  61
# Best Individual:
# [[(0.629, 0.741, 0), (0.055, 0.27, 1)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 144434
# ------------------------------------------------------------
# Generation:  62
# Best Individual:
# [[(0.055, 0.27, 1)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 143770
# ------------------------------------------------------------
# Generation:  63
# Best Individual:
# [[(0.629, 0.741, 0)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 143244
# ------------------------------------------------------------
# Generation:  64
# Best Individual:
# [[(0.055, 0.27, 1)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 144097
# ------------------------------------------------------------
# Generation:  65
# Best Individual:
# [[(0.629, 0.741, 0), (0.055, 0.27, 1), (0.113, 0.207, 0)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 143953
# ------------------------------------------------------------
# Generation:  66
# Best Individual:
# [[(0.629, 0.741, 0), (0.874, 0.943, 0)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 143845
# ------------------------------------------------------------
# Generation:  67
# Best Individual:
# [[(0.055, 0.27, 1)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 144372
# ------------------------------------------------------------
# Generation:  68
# Best Individual:
# [[(0.629, 0.741, 0), (0.055, 0.27, 1), (0.113, 0.207, 0), (0.682, 0.982, 1), (0.611, 0.993, 0)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 143954
# ------------------------------------------------------------
# Generation:  69
# Best Individual:
# [[(0.055, 0.27, 1)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 144561
# ------------------------------------------------------------
# Generation:  70
# Best Individual:
# [[(0.629, 0.741, 0), (0.055, 0.27, 1), (0.113, 0.207, 0), (0.682, 0.982, 1), (0.712, 0.95, 0), (0.637, 0.668, 1)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 143740
# ------------------------------------------------------------
# Generation:  71
# Best Individual:
# [[(0.629, 0.741, 0), (0.055, 0.27, 1), (0.113, 0.207, 0), (0.682, 0.982, 1), (0.712, 0.95, 0), (0.637, 0.668, 1)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 144478
# ------------------------------------------------------------
# Generation:  72
# Best Individual:
# [[(0.629, 0.741, 0), (0.055, 0.27, 1), (0.113, 0.207, 0), (0.682, 0.982, 1), (0.712, 0.95, 0), (0.637, 0.668, 1)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 143919
# ------------------------------------------------------------
# Generation:  73
# Best Individual:
# [[(0.055, 0.27, 1)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0), (0.007, 0.318, 1)]]
# Best Fitness:
# 143837
# ------------------------------------------------------------
# Generation:  74
# Best Individual:
# [[(0.055, 0.27, 1)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 144351
# ------------------------------------------------------------
# Generation:  75
# Best Individual:
# [[(0.055, 0.27, 1)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 144170
# ------------------------------------------------------------
# Generation:  76
# Best Individual:
# [[(0.055, 0.27, 1)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 143911
# ------------------------------------------------------------
# Generation:  77
# Best Individual:
# [[(0.055, 0.27, 1)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 144285
# ------------------------------------------------------------
# Generation:  78
# Best Individual:
# [[(0.055, 0.27, 1)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 144176
# ------------------------------------------------------------
# Generation:  80
# Best Individual:
# [[(0.055, 0.27, 1)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 143616
# ------------------------------------------------------------
# Generation:  81
# Best Individual:
# [[(0.055, 0.27, 1)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 144902
# ------------------------------------------------------------
# Generation:  82
# Best Individual:
# [[(0.055, 0.27, 1)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 144412
# ------------------------------------------------------------
# Generation:  83
# Best Individual:
# [[(0.055, 0.27, 1)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 143570
# ------------------------------------------------------------
# Generation:  84
# Best Individual:
# [[(0.055, 0.27, 1)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 143781
# ------------------------------------------------------------
# Generation:  85
# Best Individual:
# [[(0.055, 0.27, 1)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 144743
# ------------------------------------------------------------
# Generation:  86
# Best Individual:
# [[(0.055, 0.27, 1)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 144223
# ------------------------------------------------------------
# Generation:  87
# Best Individual:
# [[(0.055, 0.27, 1)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 143986
# ------------------------------------------------------------
# Generation:  88
# Best Individual:
# [[(0.055, 0.27, 1)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 144062
# ------------------------------------------------------------
# Generation:  89
# Best Individual:
# [[(0.055, 0.27, 1)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 143689
# ------------------------------------------------------------
# Generation:  90
# Best Individual:
# [[(0.055, 0.27, 1)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 144091
# ------------------------------------------------------------
# Generation:  91
# Best Individual:
# [[(0.055, 0.27, 1)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 144496
# ------------------------------------------------------------
# Generation:  92
# Best Individual:
# [[(0.055, 0.27, 1)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 144318
# ------------------------------------------------------------
# Generation:  93
# Best Individual:
# [[(0.055, 0.27, 1), (0.037, 0.253, 0)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 143119
# ------------------------------------------------------------
# Generation:  94
# Best Individual:
# [[(0.055, 0.27, 1), (0.037, 0.253, 0)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 144799
# ------------------------------------------------------------
# Generation:  95
# Best Individual:
# [[(0.055, 0.27, 1)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 144341
# ------------------------------------------------------------
# Generation:  96
# Best Individual:
# [[(0.037, 0.253, 0)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 143955
# ------------------------------------------------------------
# Generation:  97
# Best Individual:
# [[(0.055, 0.27, 1), (0.633, 0.688, 0)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 144084
# ------------------------------------------------------------
# Generation:  98
# Best Individual:
# [[(0.055, 0.27, 1), (0.633, 0.688, 0)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 143962
# ------------------------------------------------------------
# Generation:  99
# Best Individual:
# [[(0.055, 0.27, 1), (0.633, 0.688, 0)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 144535
# ------------------------------------------------------------
# Generation:  100
# Best Individual:
# [[(0.055, 0.27, 1), (0.633, 0.688, 0)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 144258
# ------------------------------------------------------------
# Generation:  101
# Best Individual:
# [[(0.055, 0.27, 1), (0.633, 0.688, 0)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 143797
# ------------------------------------------------------------
# Generation:  102
# Best Individual:
# [[(0.633, 0.688, 0)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 144220
# ------------------------------------------------------------
# Generation:  103
# Best Individual:
# [[(0.633, 0.688, 0)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 144131
# ------------------------------------------------------------
# Generation:  104
# Best Individual:
# [[(0.633, 0.688, 0)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 143987
# ------------------------------------------------------------
# Generation:  105
# Best Individual:
# [[(0.633, 0.688, 0)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 144483
# ------------------------------------------------------------
# Generation:  106
# Best Individual:
# [[(0.633, 0.688, 0)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 143819
# ------------------------------------------------------------
# Generation:  107
# Best Individual:
# [[(0.633, 0.688, 0)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 144405
# ------------------------------------------------------------
# Generation:  108
# Best Individual:
# [[(0.633, 0.688, 0)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 143771
# ------------------------------------------------------------
# Generation:  109
# Best Individual:
# [[(0.633, 0.688, 0)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 144190
# ------------------------------------------------------------
# Generation:  110
# Best Individual:
# [[(0.633, 0.688, 0)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 144210
# ------------------------------------------------------------
# Generation:  111
# Best Individual:
# [[(0.633, 0.688, 0)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 144679
# ------------------------------------------------------------
# Generation:  112
# Best Individual:
# [[(0.633, 0.688, 0)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 143370
# ------------------------------------------------------------
# Generation:  113
# Best Individual:
# [[(0.633, 0.688, 0)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 144299
# ------------------------------------------------------------
# Generation:  114
# Best Individual:
# [[(0.633, 0.688, 0)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 144609
# ------------------------------------------------------------
# Generation:  115
# Best Individual:
# [[(0.633, 0.688, 0)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 144975
# ------------------------------------------------------------
# Generation:  116
# Best Individual:
# [[(0.633, 0.688, 0)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 143029
# ------------------------------------------------------------
# Generation:  117
# Best Individual:
# [[(0.633, 0.688, 0)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 144821
# ------------------------------------------------------------
# Generation:  118
# Best Individual:
# [[(0.633, 0.688, 0)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 144068
# ------------------------------------------------------------
# Generation:  119
# Best Individual:
# [[(0.633, 0.688, 0)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0)]]
# Best Fitness:
# 143431
# ------------------------------------------------------------
# Generation:  120
# Best Individual:
# [[(0.633, 0.688, 0)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0), (0.638, 0.895, 0)]]
# Best Fitness:
# 143796
# ------------------------------------------------------------
# Generation:  121
# Best Individual:
# [[(0.633, 0.688, 0)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0), (0.638, 0.895, 0)]]
# Best Fitness:
# 143499
# ------------------------------------------------------------
# Generation:  122
# Best Individual:
# [[(0.633, 0.688, 0)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0), (0.638, 0.895, 0)]]
# Best Fitness:
# 143902
# ------------------------------------------------------------
# Generation:  123
# Best Individual:
# [[(0.633, 0.688, 0)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0), (0.638, 0.895, 0)]]
# Best Fitness:
# 144175
# ------------------------------------------------------------
# Generation:  124
# Best Individual:
# [[(0.732, 0.967, 1)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0), (0.127, 0.24, 1)]]
# Best Fitness:
# 144401
# ------------------------------------------------------------
# Generation:  125
# Best Individual:
# [[(0.633, 0.688, 0)], [(0.868, 0.872, 0)], [(0.638, 0.895, 0)]]
# Best Fitness:
# 144146
# ------------------------------------------------------------
# Generation:  126
# Best Individual:
# [[(0.732, 0.967, 1)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0), (0.127, 0.24, 1)]]
# Best Fitness:
# 144098
# ------------------------------------------------------------
# Generation:  127
# Best Individual:
# [[(0.732, 0.967, 1)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0), (0.127, 0.24, 1)]]
# Best Fitness:
# 144640
# ------------------------------------------------------------
# Generation:  128
# Best Individual:
# [[(0.732, 0.967, 1), (0.006, 0.228, 0)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0), (0.127, 0.24, 1)]]
# Best Fitness:
# 144582
# ------------------------------------------------------------
# Generation:  129
# Best Individual:
# [[(0.732, 0.967, 1)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0), (0.127, 0.24, 1)]]
# Best Fitness:
# 144446
# ------------------------------------------------------------
# Generation:  130
# Best Individual:
# [[(0.732, 0.967, 1)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 144918
# ------------------------------------------------------------
# Generation:  131
# Best Individual:
# [[(0.732, 0.967, 1), (0.622, 0.833, 0)], [(0.868, 0.872, 0)], [(0.547, 0.984, 0), (0.127, 0.24, 1)]]
# Best Fitness:
# 144538
# ------------------------------------------------------------
# Generation:  132
# Best Individual:
# [[(0.732, 0.967, 1)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 143855
# ------------------------------------------------------------
# Generation:  133
# Best Individual:
# [[(0.732, 0.967, 1)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 144410
# ------------------------------------------------------------
# Generation:  134
# Best Individual:
# [[(0.732, 0.967, 1)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 143796
# ------------------------------------------------------------
# Generation:  135
# Best Individual:
# [[(0.732, 0.967, 1)], [(0.868, 0.872, 0), (0.127, 0.336, 1)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 144416
# ------------------------------------------------------------
# Generation:  136
# Best Individual:
# [[(0.732, 0.967, 1)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 144700
# ------------------------------------------------------------
# Generation:  137
# Best Individual:
# [[(0.732, 0.967, 1)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 144301
# ------------------------------------------------------------
# Generation:  138
# Best Individual:
# [[(0.732, 0.967, 1)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 144389
# ------------------------------------------------------------
# Generation:  139
# Best Individual:
# [[(0.732, 0.967, 1)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 144431
# ------------------------------------------------------------
# Generation:  140
# Best Individual:
# [[(0.732, 0.967, 1)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 144022
# ------------------------------------------------------------
# Generation:  141
# Best Individual:
# [[(0.732, 0.967, 1)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 144402
# ------------------------------------------------------------
# Generation:  142
# Best Individual:
# [[(0.732, 0.967, 1)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 144741
# ------------------------------------------------------------
# Generation:  143
# Best Individual:
# [[(0.732, 0.967, 1)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 144366
# ------------------------------------------------------------
# Generation:  144
# Best Individual:
# [[(0.732, 0.967, 1), (0.178, 0.242, 0)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 144709
# ------------------------------------------------------------
# Generation:  145
# Best Individual:
# [[(0.732, 0.967, 1)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 144305
# ------------------------------------------------------------
# Generation:  146
# Best Individual:
# [[(0.732, 0.967, 1)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 145052
# ------------------------------------------------------------
# Generation:  147
# Best Individual:
# [[(0.732, 0.967, 1)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 143753
# ------------------------------------------------------------
# Generation:  148
# Best Individual:
# [[(0.732, 0.967, 1)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 143875
# ------------------------------------------------------------
# Generation:  149
# Best Individual:
# [[(0.732, 0.967, 1)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 144364
# ------------------------------------------------------------
# Generation:  150
# Best Individual:
# [[(0.732, 0.967, 1)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 144278
# ------------------------------------------------------------
# Generation:  151
# Best Individual:
# [[(0.178, 0.242, 0), (0.795, 0.978, 0)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 144356
# ------------------------------------------------------------
# Generation:  152
# Best Individual:
# [[(0.732, 0.967, 1), (0.178, 0.242, 0), (0.795, 0.978, 0)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 144707
# ------------------------------------------------------------
# Generation:  153
# Best Individual:
# [[(0.732, 0.967, 1), (0.178, 0.242, 0), (0.795, 0.978, 0)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 145014
# ------------------------------------------------------------
# Generation:  154
# Best Individual:
# [[(0.732, 0.967, 1), (0.178, 0.242, 0), (0.795, 0.978, 0)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 144783
# ------------------------------------------------------------
# Generation:  155
# Best Individual:
# [[(0.178, 0.242, 0)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 144248
# ------------------------------------------------------------
# Generation:  157
# Best Individual:
# [[(0.178, 0.242, 0), (0.795, 0.978, 0)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 144699
# ------------------------------------------------------------
# Generation:  158
# Best Individual:
# [[(0.178, 0.242, 0)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 144188
# ------------------------------------------------------------
# Generation:  159
# Best Individual:
# [[(0.178, 0.242, 0)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 143499
# ------------------------------------------------------------
# Generation:  160
# Best Individual:
# [[(0.178, 0.242, 0)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 143956
# ------------------------------------------------------------
# Generation:  161
# Best Individual:
# [[(0.178, 0.242, 0)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 143738
# ------------------------------------------------------------
# Generation:  162
# Best Individual:
# [[(0.178, 0.242, 0)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1), (0.11, 0.301, 0)]]
# Best Fitness:
# 145206
# ------------------------------------------------------------
# Generation:  163
# Best Individual:
# [[(0.178, 0.242, 0)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 144509
# ------------------------------------------------------------
# Generation:  164
# Best Individual:
# [[(0.178, 0.242, 0)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 144245
# ------------------------------------------------------------
# Generation:  165
# Best Individual:
# [[(0.178, 0.242, 0)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 144027
# ------------------------------------------------------------
# Generation:  166
# Best Individual:
# [[(0.178, 0.242, 0)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 145226
# ------------------------------------------------------------
# Generation:  167
# Best Individual:
# [[(0.178, 0.242, 0)], [(0.868, 0.872, 0)], [(0.11, 0.301, 0)]]
# Best Fitness:
# 144736
# ------------------------------------------------------------
# Generation:  168
# Best Individual:
# [[(0.178, 0.242, 0)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 144377
# ------------------------------------------------------------
# Generation:  169
# Best Individual:
# [[(0.178, 0.242, 0)], [(0.868, 0.872, 0)], [(0.11, 0.301, 0)]]
# Best Fitness:
# 144257
# ------------------------------------------------------------
# Generation:  170
# Best Individual:
# [[(0.178, 0.242, 0)], [(0.868, 0.872, 0)], [(0.11, 0.301, 0)]]
# Best Fitness:
# 144132
# ------------------------------------------------------------
# Generation:  171
# Best Individual:
# [[(0.178, 0.242, 0)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 143326
# ------------------------------------------------------------
# Generation:  172
# Best Individual:
# [[(0.178, 0.242, 0)], [(0.868, 0.872, 0)], [(0.11, 0.301, 0)]]
# Best Fitness:
# 144147
# ------------------------------------------------------------
# Generation:  173
# Best Individual:
# [[(0.178, 0.242, 0)], [(0.868, 0.872, 0)], [(0.11, 0.301, 0)]]
# Best Fitness:
# 144054
# ------------------------------------------------------------
# Generation:  174
# Best Individual:
# [[(0.178, 0.242, 0)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 144401
# ------------------------------------------------------------
# Generation:  175
# Best Individual:
# [[(0.178, 0.242, 0)], [(0.868, 0.872, 0)], [(0.11, 0.301, 0)]]
# Best Fitness:
# 144344
# ------------------------------------------------------------
# Generation:  176
# Best Individual:
# [[(0.178, 0.242, 0)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 143414
# ------------------------------------------------------------
# Generation:  177
# Best Individual:
# [[(0.178, 0.242, 0)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 145138
# ------------------------------------------------------------
# Generation:  178
# Best Individual:
# [[(0.178, 0.242, 0)], [(0.868, 0.872, 0)], [(0.11, 0.301, 0)]]
# Best Fitness:
# 144476
# ------------------------------------------------------------
# Generation:  179
# Best Individual:
# [[(0.178, 0.242, 0)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 144573
# ------------------------------------------------------------
# Generation:  180
# Best Individual:
# [[(0.178, 0.242, 0)], [(0.868, 0.872, 0)], [(0.11, 0.301, 0)]]
# Best Fitness:
# 143514
# ------------------------------------------------------------
# Generation:  181
# Best Individual:
# [[(0.178, 0.242, 0)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 144462
# ------------------------------------------------------------
# Generation:  182
# Best Individual:
# [[(0.178, 0.242, 0), (0.073, 0.361, 0)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 144317
# ------------------------------------------------------------
# Generation:  183
# Best Individual:
# [[(0.073, 0.361, 0)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 144657
# ------------------------------------------------------------
# Generation:  184
# Best Individual:
# [[(0.178, 0.242, 0)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 144407
# ------------------------------------------------------------
# Generation:  185
# Best Individual:
# [[(0.178, 0.242, 0)], [(0.868, 0.872, 0)], [(0.127, 0.24, 1)]]
# Best Fitness:
# 144874
# ------------------------------------------------------------
# Generation:  186
# Best Individual:
# [[(0.178, 0.242, 0), (0.584, 0.953, 0)], [(0.868, 0.872, 0)], [(0.11, 0.301, 0)]]
# Best Fitness:
# 144280
# ------------------------------------------------------------
# Generation:  187
# Best Individual:
# [[(0.178, 0.242, 0), (0.584, 0.953, 0)], [(0.868, 0.872, 0)], [(0.11, 0.301, 0)]]
# Best Fitness:
# 143914
# ------------------------------------------------------------
# Generation:  188
# Best Individual:
# [[(0.178, 0.242, 0)], [(0.868, 0.872, 0)], [(0.11, 0.301, 0)]]
# Best Fitness:
# 143658
# ------------------------------------------------------------
# Generation:  189
# Best Individual:
# [[(0.178, 0.242, 0)], [(0.868, 0.872, 0)], [(0.11, 0.301, 0)]]
# Best Fitness:
# 144019
# ------------------------------------------------------------
# Generation:  190
# Best Individual:
# [[(0.584, 0.953, 0), (0.213, 0.26, 0)], [(0.868, 0.872, 0)], [(0.11, 0.301, 0)]]
# Best Fitness:
# 143787
# ------------------------------------------------------------
# Generation:  191
# Best Individual:
# [[(0.178, 0.242, 0)], [(0.868, 0.872, 0)], [(0.11, 0.301, 0)]]
# Best Fitness:
# 144041
# ------------------------------------------------------------
# Generation:  192
# Best Individual:
# [[(0.178, 0.242, 0)], [(0.868, 0.872, 0)], [(0.11, 0.301, 0)]]
# Best Fitness:
# 144384
# ------------------------------------------------------------
# Generation:  193
# Best Individual:
# [[(0.178, 0.242, 0)], [(0.868, 0.872, 0)], [(0.11, 0.301, 0)]]
# Best Fitness:
# 143569
# ------------------------------------------------------------
# Generation:  194
# Best Individual:
# [[(0.584, 0.953, 0)], [(0.868, 0.872, 0)], [(0.11, 0.301, 0)]]
# Best Fitness:
# 144653
# ------------------------------------------------------------
# Generation:  195
# Best Individual:
# [[(0.178, 0.242, 0)], [(0.868, 0.872, 0)], [(0.11, 0.301, 0)]]
# Best Fitness:
# 144329
# ------------------------------------------------------------
# Generation:  196
# Best Individual:
# [[(0.178, 0.242, 0)], [(0.868, 0.872, 0)], [(0.11, 0.301, 0)]]
# Best Fitness:
# 144137
# ------------------------------------------------------------
# Generation:  197
# Best Individual:
# [[(0.178, 0.242, 0)], [(0.868, 0.872, 0)], [(0.11, 0.301, 0)]]
# Best Fitness:
# 143276
# ------------------------------------------------------------
# Generation:  198
# Best Individual:
# [[(0.178, 0.242, 0)], [(0.868, 0.872, 0)], [(0.11, 0.301, 0)]]
# Best Fitness:
# 144680
# ------------------------------------------------------------
# Generation:  199
# Best Individual:
# [[(0.178, 0.242, 0)], [(0.868, 0.872, 0)], [(0.11, 0.301, 0)]]
# Best Fitness:
# 144485
# ------------------------------------------------------------

# %%
155----->
