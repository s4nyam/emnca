# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(1)
def generate_rule(rule_number):
    rule = np.zeros(8, dtype=int)
    binary = np.binary_repr(rule_number, width=8)
    for i in range(8):
        rule[i] = int(binary[i])
    return rule

def apply_rule(rule, neighborhood):
    decimal = np.sum(neighborhood * np.array([1, 2, 4]))
    return rule[7 - decimal]

def simulate(rule_number, num_iterations, initial_state):
    rule = generate_rule(rule_number)
    num_cells = len(initial_state)
    state = np.zeros((num_iterations, num_cells), dtype=int)
    state[0] = initial_state

    for i in range(1, num_iterations):
        for j in range(num_cells):
            neighborhood = state[i - 1, (j - 1) % num_cells], state[i - 1, j], state[i - 1, (j + 1) % num_cells]
            state[i, j] = apply_rule(rule, neighborhood)

    return state

def visualize(rule_number, num_iterations, initial_state):
    state = simulate(rule_number, num_iterations, initial_state)

    fig, ax = plt.subplots()
    ax.imshow(state, cmap='Greys', interpolation='nearest')
    ax.set_xticks([])
    ax.set_yticks([])
    plt.savefig(f'rule_{rule_number}.png')
    plt.close()

# Simulate and visualize all possible 1D cellular automata rules
for rule_number in range(256):
    initial_state = np.zeros(101, dtype=int) # 101 1D Cells
    initial_state[50] = 1  # Set the middle cell as the initial state

    visualize(rule_number, 100, initial_state)

# %%
import os
import base64
from IPython.display import display, HTML

def display_pngs(directory):
    html = '<table>'
    filenames = [filename for filename in os.listdir(directory) if filename.endswith(".png") and '_' in filename]
    filenames = sorted(filenames, key=lambda x: int(x.split('_')[1].split('.')[0]))
    for filename in filenames:
        filepath = os.path.join(directory, filename)
        with open(filepath, "rb") as f:
            image_data = f.read()
            base64_encoded = base64.b64encode(image_data).decode('utf-8')
            html += f'<tr><td>{filename}</td><td><img src="data:image/png;base64,{base64_encoded}" /></td></tr>'
    html += '</table>'
    display(HTML(html))

# Provide the directory path where your PNG files are located
directory_path = "."

display_pngs(directory_path)
# Out:
# <table><tr><td>rule_0.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_1.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_2.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_3.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_4.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_5.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_6.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_7.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_8.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_9.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_10.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_11.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_12.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_13.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_14.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_15.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_16.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_17.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_18.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_19.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_20.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_21.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_22.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_23.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_24.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_25.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_26.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_27.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_28.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_29.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_30.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_31.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_32.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_33.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_34.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_35.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_36.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_37.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_38.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_39.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_40.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_41.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_42.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_43.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_44.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_45.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_46.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_47.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_48.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_49.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_50.png</td><td><img src="data:image/png;base64,..." /></td></tr><tr><td>rule_51.png</td><td><img src="data:image/png;base64,..." /></td></tr ...
