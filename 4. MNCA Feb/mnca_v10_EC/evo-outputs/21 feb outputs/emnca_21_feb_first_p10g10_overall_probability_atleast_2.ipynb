# %%
# !sudo pip install deflate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.2/167.2 KB 4.3 MB/s eta 0:00:00
# ...

# %%
# OVERALL_PROBABILITY_ATLEAST = 2
# !python3 EC.py
# Out:
# Generation: 0, Iteration 0, New Best Found Rule set [[(0.268, 0.515, 1), (0.841, 0.862, 0), (0.114, 0.956, 0)], [(0.583, 0.861, 0), (0.638, 0.965, 0), (0.217, 0.607, 1)], [(0.724, 0.889, 1), (0.476, 0.872, 0), (0.926, 0.952, 0)]] Deflate 108753
# Generation: 0, Iteration 1, New Best Found Rule set [[(0.268, 0.515, 1), (0.114, 0.956, 0)], [(0.583, 0.861, 0), (0.638, 0.965, 0), (0.217, 0.607, 1)], [(0.724, 0.889, 1), (0.476, 0.872, 0), (0.926, 0.952, 0)]] Deflate 108753
# Generation: 0, Iteration 2, New Best Found Rule set [[(0.682, 0.968, 1), (0.619, 0.84, 1)], [(0.122, 0.666, 0), (0.002, 0.592, 1), (0.645, 0.698, 1), (0.3, 0.651, 0)], [(0.593, 0.903, 1), (0.187, 0.596, 0), (0.217, 0.788, 0), (0.078, 0.917, 1)]] Deflate 90483
# Generation: 0, Iteration 3, New Best Found Rule set [[(0.682, 0.968, 1), (0.619, 0.84, 1)], [(0.122, 0.666, 0), (0.002, 0.592, 1), (0.645, 0.698, 1), (0.3, 0.651, 0)], [(0.593, 0.903, 1), (0.187, 0.596, 0), (0.217, 0.788, 0), (0.078, 0.917, 1)]] Deflate 90483
# ...
