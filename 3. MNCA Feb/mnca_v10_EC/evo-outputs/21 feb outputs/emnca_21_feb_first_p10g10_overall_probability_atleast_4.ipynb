# %%
# !sudo pip install deflate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# OVERALL_PROBABILITY_ATLEAST = 4
# !python3 EC.py
# Out:
# Generation: 0, Iteration 0, New Best Found Rule set [[(0.462, 0.724, 1), (0.317, 0.593, 1), (0.052, 0.947, 0)], [(0.238, 0.82, 1), (0.782, 0.981, 1)], [(0.733, 0.886, 0), (0.314, 0.379, 0), (0.396, 0.417, 1)]] Deflate 110936
# Generation: 0, Iteration 1, New Best Found Rule set [[(0.68, 0.777, 0), (0.471, 0.873, 1), (0.925, 0.937, 1), (0.225, 0.879, 1)], [(0.591, 0.985, 0), (0.327, 0.71, 1), (0.113, 0.832, 0)], [(0.784, 0.826, 0), (0.793, 0.851, 0), (0.686, 0.879, 0)]] Deflate 19415
# Generation: 0, Iteration 2, New Best Found Rule set [[(0.671, 0.919, 0), (0.768, 0.997, 0), (0.179, 0.345, 1)], [(0.011, 0.051, 0), (0.897, 0.989, 1), (0.041, 0.495, 0)], [(0.271, 0.366, 0), (0.862, 0.867, 0), (0.95, 0.953, 1)]] Deflate 54293
# Generation: 0, Iteration 3, New Best Found Rule set [[(0.483, 0.98, 0), (0.626, 0.704, 0)], [(0.909, 0.963, 0), (0.663, 0.695, 1)], [(0.505, 0.792, 0), (0.72, 0.962, 1), (0.649, 0.979, 0)]] Deflate 52123
# ...
