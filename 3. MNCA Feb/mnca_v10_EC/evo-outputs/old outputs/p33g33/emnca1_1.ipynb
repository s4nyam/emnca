# %%
# !sudo pip install deflate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python3 EC.py
# Out:
# Generation: 0, Iteration 0, New Best Found Rule set [[(0.856, 0.96, 0), (0.867, 0.979, 1), (0.051, 0.763, 0)], [(0.37, 0.795, 1), (0.774, 0.902, 0), (0.439, 0.502, 0)], [(0.161, 0.828, 1), (0.977, 0.999, 1), (0.238, 0.805, 0)]]
# Generation: 0, Iteration 1, New Best Found Rule set [[(0.682, 0.831, 1), (0.782, 0.877, 1), (0.67, 0.994, 0)], [(0.777, 0.839, 0), (0.753, 0.846, 1), (0.327, 0.527, 1)], [(0.262, 0.969, 0), (0.493, 0.968, 0), (0.01, 0.801, 0)]]
# Generation: 0, Iteration 2, New Best Found Rule set [[(0.876, 0.967, 1), (0.299, 0.399, 1), (0.866, 0.946, 1)], [(0.274, 0.505, 0), (0.088, 0.61, 1), (0.395, 0.603, 0)], [(0.276, 0.417, 1), (0.824, 0.958, 1), (0.523, 0.91, 1)]]
# Generation: 0, Iteration 3, New Best Found Rule set [[(0.192, 0.906, 0), (0.67, 0.983, 1), (0.635, 0.798, 1)], [(0.401, 0.753, 0), (0.593, 0.689, 0), (0.248, 0.446, 1)], [(0.495, 0.652, 0), (0.705, 0.853, 0), (0.288, 0.591, 1)]]
# ...
