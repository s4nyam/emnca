# %%
# Setting up neighborhoods
# !wget https://dl3.pushbulletusercontent.com/Ro4uYYu9ThNyLCx7yDFhnuvl9ZUajx38/mask_c1.txt
# !wget https://dl3.pushbulletusercontent.com/14l3I2G8NjC1ALwJkMLwrfW17bkpqEl1/mask_c2.txt
# !wget https://dl3.pushbulletusercontent.com/RD728OQjsbGtevDXSclUfD8EmWYa5BUL/mask_c3.txt

# !mkdir neighborhoods
# !mv *.txt neighborhoods
# Out:
# --2023-03-12 15:23:11--  https://dl3.pushbulletusercontent.com/Ro4uYYu9ThNyLCx7yDFhnuvl9ZUajx38/mask_c1.txt
# Resolving dl3.pushbulletusercontent.com (dl3.pushbulletusercontent.com)... 35.208.62.122
# Connecting to dl3.pushbulletusercontent.com (dl3.pushbulletusercontent.com)|35.208.62.122|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1681 (1.6K) [text/plain]
# Saving to: ‘mask_c1.txt’
#
# mask_c1.txt         100%[===================>]   1.64K  --.-KB/s    in 0s
#
# 2023-03-12 15:23:11 (18.4 MB/s) - ‘mask_c1.txt’ saved [1681/1681]
#
# --2023-03-12 15:23:11--  https://dl3.pushbulletusercontent.com/14l3I2G8NjC1ALwJkMLwrfW17bkpqEl1/mask_c2.txt
# Resolving dl3.pushbulletusercontent.com (dl3.pushbulletusercontent.com)... 35.208.62.122
# Connecting to dl3.pushbulletusercontent.com (dl3.pushbulletusercontent.com)|35.208.62.122|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1681 (1.6K) [text/plain]
# Saving to: ‘mask_c2.txt’
#
# mask_c2.txt         100%[===================>]   1.64K  --.-KB/s    in 0s
#
# 2023-03-12 15:23:11 (22.9 MB/s) - ‘mask_c2.txt’ saved [1681/1681]
#
# --2023-03-12 15:23:11--  https://dl3.pushbulletusercontent.com/RD728OQjsbGtevDXSclUfD8EmWYa5BUL/mask_c3.txt
# Resolving dl3.pushbulletusercontent.com (dl3.pushbulletusercontent.com)... 35.208.62.122
# Connecting to dl3.pushbulletusercontent.com (dl3.pushbulletusercontent.com)|35.208.62.122|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1681 (1.6K) [text/plain]
# Saving to: ‘mask_c3.txt’
#
# mask_c3.txt         100%[===================>]   1.64K  --.-KB/s    in 0s
#
# 2023-03-12 15:23:12 (27.0 MB/s) - ‘mask_c3.txt’ saved [1681/1681]

# %%
# !sudo pip install deflate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting deflate
#   Downloading deflate-0.3.0-cp39-cp39-manylinux2010_x86_64.whl (167 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.0/167.0 KB 4.0 MB/s eta 0:00:00
# Installing collected packages: deflate
# Successfully installed deflate-0.3.0

# %%
# MNCA (Fixed)
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import deflate
import os
import sys
np.set_printoptions(threshold=sys.maxsize)



def extract_neighborhood_from_file(file_name):
    with open(file_name, "r") as f:
        lines = f.readlines()
        neighborhood = []
        for i, line in enumerate(lines):
            line = line.strip()
            for j, value in enumerate(line.split(" ")):
                if value == "1":
                    neighborhood.append((i-1, j-1))
        return neighborhood



def init_board(width, height, init_state):
    if init_state == "single cell in center":
        board = np.zeros((height, width), dtype=np.int)
        board[height//2, width//2] = 1
    elif init_state == "random cells with some probability":
        p = 0.50 # probability of a cell being alive
        board = np.random.choice([0, 1], size=(height, width), p=[1-p, p])
    elif init_state == "random cells with 2 different states":
        p1 = 0.40 # probability of a cell being state 1
        board = np.random.choice([0, 1, 2], size=(height, width), p=[1-p1, p1/2, p1/2])
    else:
        raise ValueError("Invalid initial state")
    return board

def mnca(range_of_neighborhood_sums):   

    ###############----CONSTANTS----###############
    width = 100
    height = 100
    steps = 50
    init_state = "random cells with some probability"
    # Fixed Neighbohoods
    nh1 = extract_neighborhood_from_file('neighborhoods/mask_c1.txt')
    nh2 = extract_neighborhood_from_file('neighborhoods/mask_c2.txt')
    nh3 = extract_neighborhood_from_file('neighborhoods/mask_c3.txt')

    neighborhoods = [nh1,nh2,nh3]
    # neighborhoods = [nh1,nh2]
    board_arr = []
    board = init_board(width, height, init_state)
    ###############----CONSTANTS----###############


    for eachstep in range(steps):
        new_board = np.zeros_like(board, dtype=int)
        height, width = board.shape
        for i in range(height):
            for j in range(width):
                next_state = board[i, j]
                for neighborhood, range_of_neighborhood_sum in zip(neighborhoods, range_of_neighborhood_sums):
                    cell_neighborhood = [board[(i + ni + height) % height, (j + nj + width) % width]
                                        for ni, nj in neighborhood]
                    
                    # # use this for sum
                    # neighborhood_sum = sum(cell_neighborhood)
                    
                    # use this for average
                    neighborhood_sum = sum(cell_neighborhood)/len(cell_neighborhood)
                    for lower, upper, new_next_state in range_of_neighborhood_sum:
                        if lower <= neighborhood_sum <= upper:
                            next_state = new_next_state
                new_board[i, j] = next_state
        board[:] = new_board[:]
        board_arr.append(board)
    # Calculate Deflate over that board array
    
    try:
        os.remove("board_arrays.txt")
        # print("Removed Successfully")
    except:
        pass
    with open("board_arrays.txt", "w") as output:
        output.write(str(board_arr))
    
    # filedata = open('board_arrays.txt', "rb").readlines()
    # print(filedata)
    filedata = open('board_arrays.txt', 'r', encoding='utf-8').readlines()
    filedata = ''.join(filedata).encode('utf-8')
    # print(filedata)
    compressed = deflate.gzip_compress(filedata, 8)
    deflate_value = compressed.__sizeof__()
    os.system("rm *.txt")
    return deflate_value



# # Testing handlers

# nh_sum1 = [(0.210,0.220,1),(0.350, 0.500, 0), (0.750, 0.850, 0)]
# nh_sum2 = [(0.100,0.280,0),(0.430, 0.550, 1), (0.120, 0.150, 0)]
# range_of_neighborhood_sums = [nh_sum1,nh_sum2]
# print(mnca(range_of_neighborhood_sums))

# %%
import numpy as np
import sys
import random
np.set_printoptions(threshold=sys.maxsize)

OVERALL_PROBABILITY_ATLEAST = 1
POPULATION_SIZE = 10 #3
GENERATION_SIZE = 20 #3
NUMBER_OF_NEIGHBORHOODS = 3 # for random number of nh put random function here
NUMBER_OF_BOUNDS_IN_EACH_NEIGHBORHOOD = 3 # for random number of nh bounds put random function here

total_sum = 3*NUMBER_OF_NEIGHBORHOODS*NUMBER_OF_BOUNDS_IN_EACH_NEIGHBORHOOD
# total_sum = 3*POPULATION_SIZE*NUMBER_OF_NEIGHBORHOODS*NUMBER_OF_BOUNDS_IN_EACH_NEIGHBORHOOD


PROBABILITY_OF_INSERTING_A_NEW_RULE = OVERALL_PROBABILITY_ATLEAST/total_sum
PROBABILITY_OF_REMOVING_A_RULE = OVERALL_PROBABILITY_ATLEAST/total_sum
PROBABILITY_OF_CHANGING_A_RULE = OVERALL_PROBABILITY_ATLEAST/total_sum
# we take average as gene rather than sum because for sum we need to consider radius each time

# GENERATE RANDOM RULE
def generate_random_rule():
    number_of_neighborhood = NUMBER_OF_NEIGHBORHOODS
    number_of_bounds_in_each_neighborhod_average_or_sum = NUMBER_OF_BOUNDS_IN_EACH_NEIGHBORHOOD
    rule = []
    for i in range(number_of_neighborhood):
        ranges = []
        for j in range(number_of_bounds_in_each_neighborhod_average_or_sum):
            lower = round(random.uniform(0, 1),3)
            upper = round(random.uniform(lower, 1),3)
            new_next_state = random.choice([0, 1]) # for 2 states
            # new_next_state = random.choice([0, 1, 2]) # for 3 states
            ranges.append((lower, upper, new_next_state))
        rule.append(ranges)
    return rule

# print(generate_random_rule())



# POPULATION
def init_population():
    population_size = POPULATION_SIZE
    population = []
    for i in range(population_size):
        individual = generate_random_rule()
        population.append(individual)
    return population


# print(init_population())

# FITNESS / DEFLATE
def calculate_deflate(genotype):
    deflate = mnca(genotype)
    return deflate

# poopulation = init_population()
# print(calculate_deflate(poopulation[0]))


# PROPORTIONATE SELECTION / ROULETTTE WHEEL SELECTION
def roulette_wheel_selection(population, fitness_values):

    sorted_population = [x for _,x in sorted(zip(fitness_values,population))]
    sorted_fitness_scores = [_ for _,x in sorted(zip(fitness_values,population))]
    fitness_values = sorted_fitness_scores
    population = sorted_population
    total_fitness = sum(fitness_values)
    probability_values = [fitness/total_fitness for fitness in fitness_values]
    cumulative_probability = np.cumsum(probability_values)
    selected_index = None
    random_value = random.uniform(0, 1)
    for i in range(len(population)):
        if random_value < cumulative_probability[i]:
            selected_index = i
            break

    return population[selected_index], fitness_values[selected_index]


# population = init_population()
# print("-----Intial Pop-----")
# print(population)
# print("-----Fitness Values-----")
# fitness_values = [calculate_deflate(individual) for individual in population]
# print(fitness_values)
# print("-----Selected Individual-----")
# selected_individual = roulette_wheel_selection(population, fitness_values)
# print(selected_individual)

# MUTATION FOR ADDING COMPLETELY NEW BOUND. PROMOTEES DIVERSITY.
def mutation(rule):
    try:
        print("►►►► in mutation function rule before mutation: ",str(rule))
        number_of_neighborhoods = len(rule)
        for i in range(number_of_neighborhoods):
            number_of_bounds = len(rule[i])
            for j in range(number_of_bounds):
                prob_insert = PROBABILITY_OF_INSERTING_A_NEW_RULE
                prob_remove = PROBABILITY_OF_REMOVING_A_RULE
                prob_change = PROBABILITY_OF_CHANGING_A_RULE
                random_value = random.uniform(0, 1)
                print("►►►►Probabilities of insert {}, remove {} and change {}.".format(prob_insert,prob_remove,prob_change))
                print("►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation")
                print("►►►►Value of tossed coin is: ", random_value)
                # insert a value in the tuple rule
                if random_value < prob_insert:
                    print("►►►► In insertion mutation now ►►►►")
                    new_bound = []
                    # lower = rule[i][j][0]
                    # upper = rule[i][j][1]
                    # new_next_state = rule[i][j][2]
                    # toss_a_coin = random.uniform(0,1)
                    # if(toss_a_coin<0.33):
                    #     lower = round(random.uniform(0, 1),3)
                    # elif(0.33<toss_a_coin<0.66):
                    #     upper = round(random.uniform(lower, 1),3)
                    # else:
                    #     new_next_state = random.choice([0, 1])
                    lower = round(random.uniform(0, 1),3)
                    upper = round(random.uniform(0, 1),3)
                    new_next_state = random.choice([0, 1])
                    if(lower>upper):
                        temp = lower
                        lower = upper
                        upper = temp
                    new_bound.append((lower, upper, new_next_state))
                    print("►►►►rule before insert mutation: ", str(rule))
                    rule[i].extend(new_bound)
                    print("►►►► ►►►► In insertion part of the mutation code ►►►► ►►►►")
                    print("►►►►rule after insert mutation: ", str(rule))
                    print("the bound that has been added is: ",str(new_bound))
                    print("\n")
                # remove a tuple from the rule
                elif prob_insert <= random_value < prob_insert + prob_remove:
                    print("►►►► In removing a tuple mutation now ►►►►")
                    # add that code that allows not to wipe out the rule
                    # At least one tuple will stay in the rule set
                    # if rule length is more than 1, remove one rule tuple
                    if(len(rule[i])>1):
                        print("►►►► Rule before removing tuple mutation: ", str(rule))
                        removed_rule = rule[i].pop(j)
                        number_of_bounds -= 1
                        j -= 1
                        print("►►►► Rule after removing tuple mutation: ", str(rule))
                        print("►►►► rule removed is: ", removed_rule)
                        print("\n")

                    # if rule length is exactly 1 you cannot wipe out the rule, in that case
                    # perform mutation again. And it repeats till it does not fall in this code section.
                    else:
                        print("►►►► since the size of tuple is already small, not deleting anything, but sending again for mutation ►►►►")
                        print("►►►► the rule is: ", str(rule))
                        mutation(rule[i])
                    
                
                # change a tuple from the rule by adding a small change
                elif prob_insert + prob_remove <= random_value < prob_insert + prob_remove + prob_change:
                    print("►►►► In change a tuple from the rule by adding a small change mutation part ►►►►")
                    # lower = round(random.uniform(0, 1),3)
                    # upper = round(random.uniform(lower, 1),3)
                    # new_next_state = random.choice([0, 1])
                    delta = random.uniform(-0.100,0.100)
                    print("►►►► the rule before mutation is: ", str(rule))
                    print("►►►► delta introduced here: ", delta)
                    # if(rule[i][j][0]+delta<1 and rule[i][j][1]+delta>0 and rule[i][j][0]+delta< rule[i][j][1]+delta):
                    #     rule[i][j] = (round(rule[i][j][0]+(delta)), round(rule[i][j][1]+(delta)), rule[i][j][2])
                    toss_a_coin = random.uniform(0,1)
                    print("►►►► tossing another coin for tuples' three values, lower limit, upper limit and the next state: ", str(toss_a_coin))
                    if(toss_a_coin<0.33):
                        print("lower limit is going to be changed")
                        print("\n")
                        rule[i][j][0] = rule[i][j][0]+delta
                        if(rule[i][j][0] > 1):
                            rule[i][j][0] = 1
                        elif(rule[i][j][0] < 0):
                            rule[i][j][0] = 0
                    elif(0.33<toss_a_coin<0.66):
                        print("upper limit is going to be changed")
                        print("\n")
                        # rule[i][j][1] = round(random.uniform(0, 1),3)
                        rule[i][j][1] = rule[i][j][1]+delta
                        if(rule[i][j][1] > 1):
                            rule[i][j][1] = 1
                        elif(rule[i][j][1] < 0):
                            rule[i][j][1] = 0
                    else:
                        print("state value going to be changed")
                        print("\n")
                        if(rule[i][j][2] ==0):
                            rule[i][j][2] = 1
                        else:
                            rule[i][j][2] = 0
                    if(rule[i][j][0] > rule[i][j][1]):
                        temp = rule[i][j][0]
                        rule[i][j][0] = rule[i][j][1]
                        rule[i][j][1] = temp
                else:
                  print("►►►►►►►►No change")
                print("\n")
        print("►►►► ending in mutation function rule after mutation",str(rule))
        print("\n New loop of mutation starts here")
    except:
        # print("exception occured")
        pass
    return rule

# pop = init_population()
# print(pop[0])
# print("------------------------")
# print(mutation(pop[0]))

# # CROSSOVER
# def crossover(parent1, parent2):
#     number_of_neighborhoods = len(parent1)
#     child = []
#     for i in range(number_of_neighborhoods):
#         number_of_bounds = len(parent1[i])
#         bounds = []
#         for j in range(number_of_bounds):
#             parent1_bound = parent1[i][j]
#             parent2_bound = parent2[i][j]
#             random_value = random.uniform(0, 1)
#             if random_value <= 0.5:
#                 bounds.append(parent1_bound)
#             else:
#                 bounds.append(parent2_bound)
#         child.append(bounds)
#     return child


# pop = init_population()
# print("------------------------parent 1--------------------------")
# print(pop[0])

# print("------------------------parent 2--------------------------")
# print(pop[1])
# print("------------------------Child--------------------------")

# print(crossover(pop[0],pop[1]))

at_any_time_best_pop = []
at_any_time_best_deflates = []
deflates_for_plot = []
# GENETIC ALGORITHM
pop = init_population()
for generation in range(GENERATION_SIZE):

    print("\n")
    print("\n")
    print("\n")
    print("-----------Generation: "+str(generation)+"-----------")
    print("--------------------------------------------------")
    
    
    print("---------------------POPULATION-----------------------------")
    print("Population: ",str(pop))
    fitness_scores = [calculate_deflate(chromosome) for chromosome in pop]
    print("Fitness for the population this generation",str(fitness_scores))    
    print("------------------------------------------------------")
    print("\n")
    # print("\n")
    # print("\n")
    
    print("-------------------Selection---------------------------")
    selected_corpus_selection = []
    selected_corpus_selection_fitness = []
    for i in range(len(pop)):
        # Select chromosomes using tournament selection
        selected,fitness = roulette_wheel_selection(pop, fitness_scores)
        print("►►►► Selected rule in generation {} is : {}".format(str(generation),str(selected)))
        print("►►►► Selected rule fitness in generation {} is : {}".format(str(generation),str(fitness)))
        selected_corpus_selection.append(selected)
        selected_corpus_selection_fitness.append(fitness)
    selected_chromosomes_sorted = [x for _,x in sorted(zip(selected_corpus_selection_fitness,selected_corpus_selection))]
    selected_chromosomes_sorted_fitness = [_ for _,x in sorted(zip(selected_corpus_selection_fitness,selected_corpus_selection))]
    print("Selected Chromosmes sorted: ",selected_chromosomes_sorted)
    print("Selected Chromosmes sorted Fitness: ",selected_chromosomes_sorted_fitness)
    print("►►►► Most of the times rule selected or frequency of the rule {} with fitness in generation {} is : {}".format(str(selected_chromosomes_sorted[-1]),str(generation),str(selected_chromosomes_sorted_fitness[-1])))
    print("------------------------------------------------------")

    print("\n")
    # print("\n")
    # print("\n")
    
    print("-------------------Mutation---------------------------")
    # Check mutation function definition for debugging notes
    print("Picking chromosomes in the population for mutation")
    import copy
    mutating_pop = copy.deepcopy(pop)
    mutated_population = []
    print("Debugging while doing mutation (Entering Mutation Function and loop for mutation)")
    
    print("👋👋👋👋👋👋👋👋👋POPULATION BEFORE")
    print(pop)
    print("👋👋👋👋👋👋👋👋👋POPULATION BEFORE")
    for j in range(len(mutating_pop)):
        mutated_chromosome = mutation(mutating_pop[j])
        # Compare both lists
        mutated_population.append(mutated_chromosome)
        # print("😀😀😀😀😀😀😀😀😀Mutated pop",mutated_population)
    print("👋👋👋👋👋👋👋👋👋POPULATION AFTER")
    print(pop)
    print("👋👋👋👋👋👋👋👋👋POPULATION AFTER")

    print("\n")
    print("▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲ Debugging in mutation finally in Genetic algorithm ▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲")
    print("▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲ Debugging in mutation finally in Genetic algorithm ▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲")
    print("▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲ Debugging in mutation finally in Genetic algorithm ▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲")

    print("►►►►Population before mutation List1 ",pop)
    print("►►►►Population aafter mutation List2 ",mutated_population)
    # Get the minimum length of the two lists
    min_length = min(len(pop), len(mutated_population))

    # Loop through each element in the list up to the minimum length
    for a in range(min_length):
        # Get the minimum length of the sub-lists
        sub_min_length = min(len(pop[a]), len(mutated_population[a]))
        # Loop through each element in the sub-list up to the minimum length
        for b in range(sub_min_length):
            # Compare the elements of the two lists
            if pop[a][b] != mutated_population[a][b]:
                print("►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►")
                print(f"Element {a},{b} has changed from {pop[a][b]} to {mutated_population[a][b]}")
                print("►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►")
            # else:
            #     print("►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►")
            #     print("No change in population")
            #     print("►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►")


    pop = mutated_population      
    print("Mutated Population: ", pop)
    print("--------------------------------------------------")
    
    print("\n")
    # print("\n")
    # print("\n")

    # New code 1 march
    print("-------------------Preserving 1 Elite---------------------------")
    # preserve the elite from population itself
    elite_chromosome = selected_chromosomes_sorted[-1]
    elite_fitness = selected_chromosomes_sorted_fitness[-1]
    print("Elite Chromosome: ",elite_chromosome)
    print("Elite Chromosome Fitness: ",elite_fitness)
    # pop.append(elite_chromosome)
    
    # select elitee only on the basis of fitness and append it 
    # select adn mutate and ony 9 places has to be filled
    # mutate only remaining 9


    if(len(at_any_time_best_deflates)==0): # if elite list is empty
        at_any_time_best_deflates.append(elite_fitness)
        at_any_time_best_pop.append(elite_chromosome)
    if(elite_fitness<sorted(at_any_time_best_deflates)[-1]):
        at_any_time_best_deflates.append(calculate_deflate(at_any_time_best_pop[len(at_any_time_best_pop)-1]))
        at_any_time_best_pop.append(at_any_time_best_pop[len(at_any_time_best_pop)-1])
    else:
        at_any_time_best_deflates.append(elite_fitness)
        at_any_time_best_pop.append(elite_chromosome)
        
    print("----------------------------------------------------------------")


    print("Best Chromosome from this Generation: ",at_any_time_best_pop[-1])
    print("Best Chromosome Fitness from this Generation: ",at_any_time_best_deflates[-1])
    # deflates_for_plot.append(selected_chromosomes_sorted_fitness[-1])

    print("\n")
    print("\n")
    print("\n")

# # Select the chromosome with the highest fitness score from the final generation
# fitness_scores = [calculate_deflate(chromosome) for chromosome in at_any_time_best_pop]
# best_chromosome = at_any_time_best_pop[at_any_time_best_deflates.index(max(at_any_time_best_deflates))]
# print("FINAL BEST CHROMOSOME IS: {} with fitness score {}".format(str(best_chromosome),str(max(fitness_scores))))
# # return best_chromosome


import matplotlib.pyplot as plt
plt.plot(at_any_time_best_deflates)
plt.xlabel('Generations')
plt.ylabel('Deflates')
plt.savefig("plot.png")
# Out:
# Streaming output truncated to the last 5000 lines.
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.22031063483095847
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.9495935714527431
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.6648968678585468
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.10994742245514133
# ►►►► In change a tuple from the rule by adding a small change mutation part ►►►►
# ►►►► the rule before mutation is:  [[(0.446, 0.462, 1), (0.352, 0.727, 0), (0.576, 0.924, 0), (0.326, 0.398, 0)], [(0.988, 0.997, 0), (0.186, 0.414, 0), (0.025, 0.906, 0)], [(0.097, 0.372, 1), (0.691, 0.928, 1), (0.146, 0.532, 1), (0.449, 0.615, 1)]]
# ►►►► delta introduced here:  -0.08166861108734298
# ►►►► tossing another coin for tuples' three values, lower limit, upper limit and the next state:  0.6722392582257128
# state value going to be changed
#
#
# ►►►► in mutation function rule before mutation:  [[(0.861, 0.915, 0), (0.632, 0.71, 0), (0.355, 0.365, 1), (0.262, 0.788, 1), (0.593, 0.857, 1)], [(0.677, 0.768, 1), (0.733, 0.941, 0), (0.388, 0.85, 1)], [(0.733, 0.739, 1), (0.302, 0.993, 0)]]
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.7491701351165563
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.29039489229847926
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.02497725698671749
# ►►►► In insertion mutation now ►►►►
# ►►►►rule before insert mutation:  [[(0.861, 0.915, 0), (0.632, 0.71, 0), (0.355, 0.365, 1), (0.262, 0.788, 1), (0.593, 0.857, 1)], [(0.677, 0.768, 1), (0.733, 0.941, 0), (0.388, 0.85, 1)], [(0.733, 0.739, 1), (0.302, 0.993, 0)]]
# ►►►► ►►►► In insertion part of the mutation code ►►►► ►►►►
# ►►►►rule after insert mutation:  [[(0.861, 0.915, 0), (0.632, 0.71, 0), (0.355, 0.365, 1), (0.262, 0.788, 1), (0.593, 0.857, 1), (0.296, 0.42, 1)], [(0.677, 0.768, 1), (0.733, 0.941, 0), (0.388, 0.85, 1)], [(0.733, 0.739, 1), (0.302, 0.993, 0)]]
# the bound that has been added is:  [(0.296, 0.42, 1)]
#
#
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.08816590594060358
# ►►►► In change a tuple from the rule by adding a small change mutation part ►►►►
# ►►►► the rule before mutation is:  [[(0.861, 0.915, 0), (0.632, 0.71, 0), (0.355, 0.365, 1), (0.262, 0.788, 1), (0.593, 0.857, 1), (0.296, 0.42, 1)], [(0.677, 0.768, 1), (0.733, 0.941, 0), (0.388, 0.85, 1)], [(0.733, 0.739, 1), (0.302, 0.993, 0)]]
# ►►►► delta introduced here:  0.019952903934902344
# ►►►► tossing another coin for tuples' three values, lower limit, upper limit and the next state:  0.5381939479649082
# upper limit is going to be changed
#
#
# ►►►► in mutation function rule before mutation:  [[(0.899, 0.964, 1), (0.647, 0.677, 1)], [(0.125, 0.433, 0)], [(0.993, 0.994, 0), (0.759, 0.88, 1)]]
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.49789202186398784
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.8386445850400089
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.8257048409309415
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.8688436399757596
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.411501287721565
# ►►►►►►►►No change
#
#
# ►►►► ending in mutation function rule after mutation [[(0.899, 0.964, 1), (0.647, 0.677, 1)], [(0.125, 0.433, 0)], [(0.993, 0.994, 0), (0.759, 0.88, 1)]]
#
#  New loop of mutation starts here
# ►►►► in mutation function rule before mutation:  [[(0.905, 0.982, 0), (0.078, 0.313, 1), (0.061, 0.468, 1), (0.407, 0.572, 0)], [(0.538, 0.689, 0), (0.657, 0.859, 1), (0.533, 0.85, 1)], [(0.549, 0.857, 0), (0.16, 0.418, 0), (0.09, 0.734, 0), (0.111, 0.758, 1), (0.4, 0.983, 1)]]
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.08892306558856988
# ►►►► In change a tuple from the rule by adding a small change mutation part ►►►►
# ►►►► the rule before mutation is:  [[(0.905, 0.982, 0), (0.078, 0.313, 1), (0.061, 0.468, 1), (0.407, 0.572, 0)], [(0.538, 0.689, 0), (0.657, 0.859, 1), (0.533, 0.85, 1)], [(0.549, 0.857, 0), (0.16, 0.418, 0), (0.09, 0.734, 0), (0.111, 0.758, 1), (0.4, 0.983, 1)]]
# ►►►► delta introduced here:  0.09427637196242816
# ►►►► tossing another coin for tuples' three values, lower limit, upper limit and the next state:  0.5091744320901913
# upper limit is going to be changed
#
#
# ►►►► in mutation function rule before mutation:  [[(0.868, 1.0, 0), (0.327, 0.871, 1), (0.568, 0.948, 0)], [(0.768, 0.78, 0)], [(0.505, 0.594, 0), (0.647, 0.947, 1)]]
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.9049745707293253
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.9667448727554446
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.6814545828602399
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.14890256146086156
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.3471915121615389
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.9227502220987203
# ►►►►►►►►No change
#
#
# ►►►► ending in mutation function rule after mutation [[(0.868, 1.0, 0), (0.327, 0.871, 1), (0.568, 0.948, 0)], [(0.768, 0.78, 0)], [(0.505, 0.594, 0), (0.647, 0.947, 1)]]
#
#  New loop of mutation starts here
# ►►►► in mutation function rule before mutation:  [[(0.816, 0.82, 0), (0.163, 0.208, 0), (0.947, 0.958, 0), (0.252, 0.418, 0), (0.385, 0.942, 1), (0.332, 0.563, 1), (0.226, 0.279, 0), (0.469, 0.546, 1), (0.627, 0.774, 0)], [(0.491, 0.851, 0)], [(0.27, 0.769, 1), (0.253, 0.487, 1)]]
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.395057569422289
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.5379869921843299
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.4779358910978829
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.31709598876157463
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.6038651815198709
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.3877792805103797
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.2051914651985215
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.33740289605977747
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.5867986026182201
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.47228233408268316
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.5016516477833638
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.9748760515931171
# ►►►►►►►►No change
#
#
# ►►►► ending in mutation function rule after mutation [[(0.816, 0.82, 0), (0.163, 0.208, 0), (0.947, 0.958, 0), (0.252, 0.418, 0), (0.385, 0.942, 1), (0.332, 0.563, 1), (0.226, 0.279, 0), (0.469, 0.546, 1), (0.627, 0.774, 0)], [(0.491, 0.851, 0)], [(0.27, 0.769, 1), (0.253, 0.487, 1)]]
#
#  New loop of mutation starts here
# 👋👋👋👋👋👋👋👋👋POPULATION AFTER
# [[[(0.266, 0.698, 0), (0.351, 0.553, 0), (0.115, 0.461, 1), (0.153, 0.727, 0)], [(0.036, 0.074, 1), (0.818, 0.889, 0), (0.583, 0.763, 0), (0.857, 0.983, 1)], [(0.12, 0.406, 0), (0.819, 0.941, 1), (0.482, 0.693, 1)]], [[(0.723, 0.812, 0), (0.016, 0.982, 1), (0.313, 0.327, 0)], [(0.373, 0.878, 0), (0.329, 0.364, 0)], [(0.179, 0.24, 0), (0.787, 0.978, 1), (0.031, 0.755, 1)]], [[(0.4, 0.513, 1), (0.478, 0.637, 1)], [(0.935, 0.949, 1), (0.78, 0.927, 1)], [(0.464, 0.677, 0)]], [[(0.921, 0.939, 1), (0.412, 0.853, 1)], [(0.73, 0.894, 1), (0.907, 0.939, 1)], [(0.028, 0.829, 1), (0.681, 0.979, 1)]], [[(0.446, 0.462, 1), (0.352, 0.727, 0), (0.576, 0.924, 0), (0.326, 0.398, 0)], [(0.988, 0.997, 0), (0.186, 0.414, 0), (0.025, 0.906, 0)], [(0.097, 0.372, 1), (0.691, 0.928, 1), (0.146, 0.532, 1), (0.449, 0.615, 1)]], [[(0.861, 0.915, 0), (0.632, 0.71, 0), (0.355, 0.365, 1), (0.262, 0.788, 1), (0.593, 0.857, 1)], [(0.677, 0.768, 1), (0.733, 0.941, 0), (0.388, 0.85, 1)], [(0.733, 0.739, 1), (0.302, 0.993, 0)]], [[(0.899, 0.964, 1), (0.647, 0.677, 1)], [(0.125, 0.433, 0)], [(0.993, 0.994, 0), (0.759, 0.88, 1)]], [[(0.905, 0.982, 0), (0.078, 0.313, 1), (0.061, 0.468, 1), (0.407, 0.572, 0)], [(0.538, 0.689, 0), (0.657, 0.859, 1), (0.533, 0.85, 1)], [(0.549, 0.857, 0), (0.16, 0.418, 0), (0.09, 0.734, 0), (0.111, 0.758, 1), (0.4, 0.983, 1)]], [[(0.868, 1.0, 0), (0.327, 0.871, 1), (0.568, 0.948, 0)], [(0.768, 0.78, 0)], [(0.505, 0.594, 0), (0.647, 0.947, 1)]], [[(0.816, 0.82, 0), (0.163, 0.208, 0), (0.947, 0.958, 0), (0.252, 0.418, 0), (0.385, 0.942, 1), (0.332, 0.563, 1), (0.226, 0.279, 0), (0.469, 0.546, 1), (0.627, 0.774, 0)], [(0.491, 0.851, 0)], [(0.27, 0.769, 1), (0.253, 0.487, 1)]]]
# 👋👋👋👋👋👋👋👋👋POPULATION AFTER
#
#
# ▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲ Debugging in mutation finally in Genetic algorithm ▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲
# ▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲ Debugging in mutation finally in Genetic algorithm ▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲
# ▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲ Debugging in mutation finally in Genetic algorithm ▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲
# ►►►►Population before mutation List1  [[[(0.266, 0.698, 0), (0.351, 0.553, 0), (0.115, 0.461, 1), (0.153, 0.727, 0)], [(0.036, 0.074, 1), (0.818, 0.889, 0), (0.583, 0.763, 0), (0.857, 0.983, 1)], [(0.12, 0.406, 0), (0.819, 0.941, 1), (0.482, 0.693, 1)]], [[(0.723, 0.812, 0), (0.016, 0.982, 1), (0.313, 0.327, 0)], [(0.373, 0.878, 0), (0.329, 0.364, 0)], [(0.179, 0.24, 0), (0.787, 0.978, 1), (0.031, 0.755, 1)]], [[(0.4, 0.513, 1), (0.478, 0.637, 1)], [(0.935, 0.949, 1), (0.78, 0.927, 1)], [(0.464, 0.677, 0)]], [[(0.921, 0.939, 1), (0.412, 0.853, 1)], [(0.73, 0.894, 1), (0.907, 0.939, 1)], [(0.028, 0.829, 1), (0.681, 0.979, 1)]], [[(0.446, 0.462, 1), (0.352, 0.727, 0), (0.576, 0.924, 0), (0.326, 0.398, 0)], [(0.988, 0.997, 0), (0.186, 0.414, 0), (0.025, 0.906, 0)], [(0.097, 0.372, 1), (0.691, 0.928, 1), (0.146, 0.532, 1), (0.449, 0.615, 1)]], [[(0.861, 0.915, 0), (0.632, 0.71, 0), (0.355, 0.365, 1), (0.262, 0.788, 1), (0.593, 0.857, 1)], [(0.677, 0.768, 1), (0.733, 0.941, 0), (0.388, 0.85, 1)], [(0.733, 0.739, 1), (0.302, 0.993, 0)]], [[(0.899, 0.964, 1), (0.647, 0.677, 1)], [(0.125, 0.433, 0)], [(0.993, 0.994, 0), (0.759, 0.88, 1)]], [[(0.905, 0.982, 0), (0.078, 0.313, 1), (0.061, 0.468, 1), (0.407, 0.572, 0)], [(0.538, 0.689, 0), (0.657, 0.859, 1), (0.533, 0.85, 1)], [(0.549, 0.857, 0), (0.16, 0.418, 0), (0.09, 0.734, 0), (0.111, 0.758, 1), (0.4, 0.983, 1)]], [[(0.868, 1.0, 0), (0.327, 0.871, 1), (0.568, 0.948, 0)], [(0.768, 0.78, 0)], [(0.505, 0.594, 0), (0.647, 0.947, 1)]], [[(0.816, 0.82, 0), (0.163, 0.208, 0), (0.947, 0.958, 0), (0.252, 0.418, 0), (0.385, 0.942, 1), (0.332, 0.563, 1), (0.226, 0.279, 0), (0.469, 0.546, 1), (0.627, 0.774, 0)], [(0.491, 0.851, 0)], [(0.27, 0.769, 1), (0.253, 0.487, 1)]]]
# ►►►►Population aafter mutation List2  [[[(0.266, 0.698, 0), (0.351, 0.553, 0), (0.115, 0.461, 1), (0.153, 0.727, 0)], [(0.036, 0.074, 1), (0.818, 0.889, 0), (0.583, 0.763, 0), (0.857, 0.983, 1)], [(0.12, 0.406, 0), (0.819, 0.941, 1), (0.482, 0.693, 1)]], [[(0.723, 0.812, 0), (0.016, 0.982, 1), (0.313, 0.327, 0)], [(0.373, 0.878, 0), (0.329, 0.364, 0)], [(0.179, 0.24, 0), (0.787, 0.978, 1), (0.031, 0.755, 1)]], [[(0.4, 0.513, 1), (0.478, 0.637, 1)], [(0.935, 0.949, 1), (0.78, 0.927, 1)], [(0.464, 0.677, 0)]], [[(0.921, 0.939, 1), (0.412, 0.853, 1)], [(0.73, 0.894, 1), (0.907, 0.939, 1), (0.518, 0.587, 1)], [(0.028, 0.829, 1), (0.681, 0.979, 1)]], [[(0.446, 0.462, 1), (0.352, 0.727, 0), (0.576, 0.924, 0), (0.326, 0.398, 0)], [(0.988, 0.997, 0), (0.186, 0.414, 0), (0.025, 0.906, 0)], [(0.097, 0.372, 1), (0.691, 0.928, 1), (0.146, 0.532, 1), (0.449, 0.615, 1)]], [[(0.861, 0.915, 0), (0.632, 0.71, 0), (0.355, 0.365, 1), (0.262, 0.788, 1), (0.593, 0.857, 1), (0.296, 0.42, 1)], [(0.677, 0.768, 1), (0.733, 0.941, 0), (0.388, 0.85, 1)], [(0.733, 0.739, 1), (0.302, 0.993, 0)]], [[(0.899, 0.964, 1), (0.647, 0.677, 1)], [(0.125, 0.433, 0)], [(0.993, 0.994, 0), (0.759, 0.88, 1)]], [[(0.905, 0.982, 0), (0.078, 0.313, 1), (0.061, 0.468, 1), (0.407, 0.572, 0)], [(0.538, 0.689, 0), (0.657, 0.859, 1), (0.533, 0.85, 1)], [(0.549, 0.857, 0), (0.16, 0.418, 0), (0.09, 0.734, 0), (0.111, 0.758, 1), (0.4, 0.983, 1)]], [[(0.868, 1.0, 0), (0.327, 0.871, 1), (0.568, 0.948, 0)], [(0.768, 0.78, 0)], [(0.505, 0.594, 0), (0.647, 0.947, 1)]], [[(0.816, 0.82, 0), (0.163, 0.208, 0), (0.947, 0.958, 0), (0.252, 0.418, 0), (0.385, 0.942, 1), (0.332, 0.563, 1), (0.226, 0.279, 0), (0.469, 0.546, 1), (0.627, 0.774, 0)], [(0.491, 0.851, 0)], [(0.27, 0.769, 1), (0.253, 0.487, 1)]]]
# ►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►
# Element 3,1 has changed from [(0.73, 0.894, 1), (0.907, 0.939, 1)] to [(0.73, 0.894, 1), (0.907, 0.939, 1), (0.518, 0.587, 1)]
# ►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►
# ►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►
# Element 5,0 has changed from [(0.861, 0.915, 0), (0.632, 0.71, 0), (0.355, 0.365, 1), (0.262, 0.788, 1), (0.593, 0.857, 1)] to [(0.861, 0.915, 0), (0.632, 0.71, 0), (0.355, 0.365, 1), (0.262, 0.788, 1), (0.593, 0.857, 1), (0.296, 0.42, 1)]
# ►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►
# Mutated Population:  [[[(0.266, 0.698, 0), (0.351, 0.553, 0), (0.115, 0.461, 1), (0.153, 0.727, 0)], [(0.036, 0.074, 1), (0.818, 0.889, 0), (0.583, 0.763, 0), (0.857, 0.983, 1)], [(0.12, 0.406, 0), (0.819, 0.941, 1), (0.482, 0.693, 1)]], [[(0.723, 0.812, 0), (0.016, 0.982, 1), (0.313, 0.327, 0)], [(0.373, 0.878, 0), (0.329, 0.364, 0)], [(0.179, 0.24, 0), (0.787, 0.978, 1), (0.031, 0.755, 1)]], [[(0.4, 0.513, 1), (0.478, 0.637, 1)], [(0.935, 0.949, 1), (0.78, 0.927, 1)], [(0.464, 0.677, 0)]], [[(0.921, 0.939, 1), (0.412, 0.853, 1)], [(0.73, 0.894, 1), (0.907, 0.939, 1), (0.518, 0.587, 1)], [(0.028, 0.829, 1), (0.681, 0.979, 1)]], [[(0.446, 0.462, 1), (0.352, 0.727, 0), (0.576, 0.924, 0), (0.326, 0.398, 0)], [(0.988, 0.997, 0), (0.186, 0.414, 0), (0.025, 0.906, 0)], [(0.097, 0.372, 1), (0.691, 0.928, 1), (0.146, 0.532, 1), (0.449, 0.615, 1)]], [[(0.861, 0.915, 0), (0.632, 0.71, 0), (0.355, 0.365, 1), (0.262, 0.788, 1), (0.593, 0.857, 1), (0.296, 0.42, 1)], [(0.677, 0.768, 1), (0.733, 0.941, 0), (0.388, 0.85, 1)], [(0.733, 0.739, 1), (0.302, 0.993, 0)]], [[(0.899, 0.964, 1), (0.647, 0.677, 1)], [(0.125, 0.433, 0)], [(0.993, 0.994, 0), (0.759, 0.88, 1)]], [[(0.905, 0.982, 0), (0.078, 0.313, 1), (0.061, 0.468, 1), (0.407, 0.572, 0)], [(0.538, 0.689, 0), (0.657, 0.859, 1), (0.533, 0.85, 1)], [(0.549, 0.857, 0), (0.16, 0.418, 0), (0.09, 0.734, 0), (0.111, 0.758, 1), (0.4, 0.983, 1)]], [[(0.868, 1.0, 0), (0.327, 0.871, 1), (0.568, 0.948, 0)], [(0.768, 0.78, 0)], [(0.505, 0.594, 0), (0.647, 0.947, 1)]], [[(0.816, 0.82, 0), (0.163, 0.208, 0), (0.947, 0.958, 0), (0.252, 0.418, 0), (0.385, 0.942, 1), (0.332, 0.563, 1), (0.226, 0.279, 0), (0.469, 0.546, 1), (0.627, 0.774, 0)], [(0.491, 0.851, 0)], [(0.27, 0.769, 1), (0.253, 0.487, 1)]]]
# --------------------------------------------------
#
#
# -------------------Preserving 1 Elite---------------------------
# Elite Chromosome:  [[(0.4, 0.513, 1), (0.478, 0.637, 1)], [(0.935, 0.949, 1), (0.78, 0.927, 1)], [(0.464, 0.677, 0)]]
# Elite Chromosome Fitness:  103471
# ----------------------------------------------------------------
# Best Chromosome from this Generation:  [[(0.159, 0.506, 1), (0.899, 0.964, 1), (0.647, 0.677, 1)], [(0.544, 0.81, 0), (0.125, 0.433, 0)], [(0.993, 0.994, 0), (0.759, 0.88, 1), (0.707, 0.718, 0)]]
# Best Chromosome Fitness from this Generation:  120187
#
#
#
#
#
#
#
#
#
#
#
#
# -----------Generation: 13-----------
# --------------------------------------------------
# ---------------------POPULATION-----------------------------
# Population:  [[[(0.266, 0.698, 0), (0.351, 0.553, 0), (0.115, 0.461, 1), (0.153, 0.727, 0)], [(0.036, 0.074, 1), (0.818, 0.889, 0), (0.583, 0.763, 0), (0.857, 0.983, 1)], [(0.12, 0.406, 0), (0.819, 0.941, 1), (0.482, 0.693, 1)]], [[(0.723, 0.812, 0), (0.016, 0.982, 1), (0.313, 0.327, 0)], [(0.373, 0.878, 0), (0.329, 0.364, 0)], [(0.179, 0.24, 0), (0.787, 0.978, 1), (0.031, 0.755, 1)]], [[(0.4, 0.513, 1), (0.478, 0.637, 1)], [(0.935, 0.949, 1), (0.78, 0.927, 1)], [(0.464, 0.677, 0)]], [[(0.921, 0.939, 1), (0.412, 0.853, 1)], [(0.73, 0.894, 1), (0.907, 0.939, 1), (0.518, 0.587, 1)], [(0.028, 0.829, 1), (0.681, 0.979, 1)]], [[(0.446, 0.462, 1), (0.352, 0.727, 0), (0.576, 0.924, 0), (0.326, 0.398, 0)], [(0.988, 0.997, 0), (0.186, 0.414, 0), (0.025, 0.906, 0)], [(0.097, 0.372, 1), (0.691, 0.928, 1), (0.146, 0.532, 1), (0.449, 0.615, 1)]], [[(0.861, 0.915, 0), (0.632, 0.71, 0), (0.355, 0.365, 1), (0.262, 0.788, 1), (0.593, 0.857, 1), (0.296, 0.42, 1)], [(0.677, 0.768, 1), (0.733, 0.941, 0), (0.388, 0.85, 1)], [(0.733, 0.739, 1), (0.302, 0.993, 0)]], [[(0.899, 0.964, 1), (0.647, 0.677, 1)], [(0.125, 0.433, 0)], [(0.993, 0.994, 0), (0.759, 0.88, 1)]], [[(0.905, 0.982, 0), (0.078, 0.313, 1), (0.061, 0.468, 1), (0.407, 0.572, 0)], [(0.538, 0.689, 0), (0.657, 0.859, 1), (0.533, 0.85, 1)], [(0.549, 0.857, 0), (0.16, 0.418, 0), (0.09, 0.734, 0), (0.111, 0.758, 1), (0.4, 0.983, 1)]], [[(0.868, 1.0, 0), (0.327, 0.871, 1), (0.568, 0.948, 0)], [(0.768, 0.78, 0)], [(0.505, 0.594, 0), (0.647, 0.947, 1)]], [[(0.816, 0.82, 0), (0.163, 0.208, 0), (0.947, 0.958, 0), (0.252, 0.418, 0), (0.385, 0.942, 1), (0.332, 0.563, 1), (0.226, 0.279, 0), (0.469, 0.546, 1), (0.627, 0.774, 0)], [(0.491, 0.851, 0)], [(0.27, 0.769, 1), (0.253, 0.487, 1)]]]
# Fitness for the population this generation [57084, 19415, 112705, 19415, 20764, 19415, 80232, 19415, 83518, 19415]
# ------------------------------------------------------
#
#
# -------------------Selection---------------------------
# ►►►► Selected rule in generation 13 is : [[(0.4, 0.513, 1), (0.478, 0.637, 1)], [(0.935, 0.949, 1), (0.78, 0.927, 1)], [(0.464, 0.677, 0)]]
# ►►►► Selected rule fitness in generation 13 is : 112705
# ►►►► Selected rule in generation 13 is : [[(0.266, 0.698, 0), (0.351, 0.553, 0), (0.115, 0.461, 1), (0.153, 0.727, 0)], [(0.036, 0.074, 1), (0.818, 0.889, 0), (0.583, 0.763, 0), (0.857, 0.983, 1)], [(0.12, 0.406, 0), (0.819, 0.941, 1), (0.482, 0.693, 1)]]
# ►►►► Selected rule fitness in generation 13 is : 57084
# ►►►► Selected rule in generation 13 is : [[(0.899, 0.964, 1), (0.647, 0.677, 1)], [(0.125, 0.433, 0)], [(0.993, 0.994, 0), (0.759, 0.88, 1)]]
# ►►►► Selected rule fitness in generation 13 is : 80232
# ►►►► Selected rule in generation 13 is : [[(0.899, 0.964, 1), (0.647, 0.677, 1)], [(0.125, 0.433, 0)], [(0.993, 0.994, 0), (0.759, 0.88, 1)]]
# ►►►► Selected rule fitness in generation 13 is : 80232
# ►►►► Selected rule in generation 13 is : [[(0.905, 0.982, 0), (0.078, 0.313, 1), (0.061, 0.468, 1), (0.407, 0.572, 0)], [(0.538, 0.689, 0), (0.657, 0.859, 1), (0.533, 0.85, 1)], [(0.549, 0.857, 0), (0.16, 0.418, 0), (0.09, 0.734, 0), (0.111, 0.758, 1), (0.4, 0.983, 1)]]
# ►►►► Selected rule fitness in generation 13 is : 19415
# ►►►► Selected rule in generation 13 is : [[(0.899, 0.964, 1), (0.647, 0.677, 1)], [(0.125, 0.433, 0)], [(0.993, 0.994, 0), (0.759, 0.88, 1)]]
# ►►►► Selected rule fitness in generation 13 is : 80232
# ►►►► Selected rule in generation 13 is : [[(0.899, 0.964, 1), (0.647, 0.677, 1)], [(0.125, 0.433, 0)], [(0.993, 0.994, 0), (0.759, 0.88, 1)]]
# ►►►► Selected rule fitness in generation 13 is : 80232
# ►►►► Selected rule in generation 13 is : [[(0.868, 1.0, 0), (0.327, 0.871, 1), (0.568, 0.948, 0)], [(0.768, 0.78, 0)], [(0.505, 0.594, 0), (0.647, 0.947, 1)]]
# ►►►► Selected rule fitness in generation 13 is : 83518
# ►►►► Selected rule in generation 13 is : [[(0.4, 0.513, 1), (0.478, 0.637, 1)], [(0.935, 0.949, 1), (0.78, 0.927, 1)], [(0.464, 0.677, 0)]]
# ►►►► Selected rule fitness in generation 13 is : 112705
# ►►►► Selected rule in generation 13 is : [[(0.905, 0.982, 0), (0.078, 0.313, 1), (0.061, 0.468, 1), (0.407, 0.572, 0)], [(0.538, 0.689, 0), (0.657, 0.859, 1), (0.533, 0.85, 1)], [(0.549, 0.857, 0), (0.16, 0.418, 0), (0.09, 0.734, 0), (0.111, 0.758, 1), (0.4, 0.983, 1)]]
# ►►►► Selected rule fitness in generation 13 is : 19415
# Selected Chromosmes sorted:  [[[(0.905, 0.982, 0), (0.078, 0.313, 1), (0.061, 0.468, 1), (0.407, 0.572, 0)], [(0.538, 0.689, 0), (0.657, 0.859, 1), (0.533, 0.85, 1)], [(0.549, 0.857, 0), (0.16, 0.418, 0), (0.09, 0.734, 0), (0.111, 0.758, 1), (0.4, 0.983, 1)]], [[(0.905, 0.982, 0), (0.078, 0.313, 1), (0.061, 0.468, 1), (0.407, 0.572, 0)], [(0.538, 0.689, 0), (0.657, 0.859, 1), (0.533, 0.85, 1)], [(0.549, 0.857, 0), (0.16, 0.418, 0), (0.09, 0.734, 0), (0.111, 0.758, 1), (0.4, 0.983, 1)]], [[(0.266, 0.698, 0), (0.351, 0.553, 0), (0.115, 0.461, 1), (0.153, 0.727, 0)], [(0.036, 0.074, 1), (0.818, 0.889, 0), (0.583, 0.763, 0), (0.857, 0.983, 1)], [(0.12, 0.406, 0), (0.819, 0.941, 1), (0.482, 0.693, 1)]], [[(0.899, 0.964, 1), (0.647, 0.677, 1)], [(0.125, 0.433, 0)], [(0.993, 0.994, 0), (0.759, 0.88, 1)]], [[(0.899, 0.964, 1), (0.647, 0.677, 1)], [(0.125, 0.433, 0)], [(0.993, 0.994, 0), (0.759, 0.88, 1)]], [[(0.899, 0.964, 1), (0.647, 0.677, 1)], [(0.125, 0.433, 0)], [(0.993, 0.994, 0), (0.759, 0.88, 1)]], [[(0.899, 0.964, 1), (0.647, 0.677, 1)], [(0.125, 0.433, 0)], [(0.993, 0.994, 0), (0.759, 0.88, 1)]], [[(0.868, 1.0, 0), (0.327, 0.871, 1), (0.568, 0.948, 0)], [(0.768, 0.78, 0)], [(0.505, 0.594, 0), (0.647, 0.947, 1)]], [[(0.4, 0.513, 1), (0.478, 0.637, 1)], [(0.935, 0.949, 1), (0.78, 0.927, 1)], [(0.464, 0.677, 0)]], [[(0.4, 0.513, 1), (0.478, 0.637, 1)], [(0.935, 0.949, 1), (0.78, 0.927, 1)], [(0.464, 0.677, 0)]]]
# Selected Chromosmes sorted Fitness:  [19415, 19415, 57084, 80232, 80232, 80232, 80232, 83518, 112705, 112705]
# ►►►► Most of the times rule selected or frequency of the rule [[(0.4, 0.513, 1), (0.478, 0.637, 1)], [(0.935, 0.949, 1), (0.78, 0.927, 1)], [(0.464, 0.677, 0)]] with fitness in generation 13 is : 112705
# ------------------------------------------------------
#
#
# -------------------Mutation---------------------------
# Picking chromosomes in the population for mutation
# Debugging while doing mutation (Entering Mutation Function and loop for mutation)
# 👋👋👋👋👋👋👋👋👋POPULATION BEFORE
# [[[(0.266, 0.698, 0), (0.351, 0.553, 0), (0.115, 0.461, 1), (0.153, 0.727, 0)], [(0.036, 0.074, 1), (0.818, 0.889, 0), (0.583, 0.763, 0), (0.857, 0.983, 1)], [(0.12, 0.406, 0), (0.819, 0.941, 1), (0.482, 0.693, 1)]], [[(0.723, 0.812, 0), (0.016, 0.982, 1), (0.313, 0.327, 0)], [(0.373, 0.878, 0), (0.329, 0.364, 0)], [(0.179, 0.24, 0), (0.787, 0.978, 1), (0.031, 0.755, 1)]], [[(0.4, 0.513, 1), (0.478, 0.637, 1)], [(0.935, 0.949, 1), (0.78, 0.927, 1)], [(0.464, 0.677, 0)]], [[(0.921, 0.939, 1), (0.412, 0.853, 1)], [(0.73, 0.894, 1), (0.907, 0.939, 1), (0.518, 0.587, 1)], [(0.028, 0.829, 1), (0.681, 0.979, 1)]], [[(0.446, 0.462, 1), (0.352, 0.727, 0), (0.576, 0.924, 0), (0.326, 0.398, 0)], [(0.988, 0.997, 0), (0.186, 0.414, 0), (0.025, 0.906, 0)], [(0.097, 0.372, 1), (0.691, 0.928, 1), (0.146, 0.532, 1), (0.449, 0.615, 1)]], [[(0.861, 0.915, 0), (0.632, 0.71, 0), (0.355, 0.365, 1), (0.262, 0.788, 1), (0.593, 0.857, 1), (0.296, 0.42, 1)], [(0.677, 0.768, 1), (0.733, 0.941, 0), (0.388, 0.85, 1)], [(0.733, 0.739, 1), (0.302, 0.993, 0)]], [[(0.899, 0.964, 1), (0.647, 0.677, 1)], [(0.125, 0.433, 0)], [(0.993, 0.994, 0), (0.759, 0.88, 1)]], [[(0.905, 0.982, 0), (0.078, 0.313, 1), (0.061, 0.468, 1), (0.407, 0.572, 0)], [(0.538, 0.689, 0), (0.657, 0.859, 1), (0.533, 0.85, 1)], [(0.549, 0.857, 0), (0.16, 0.418, 0), (0.09, 0.734, 0), (0.111, 0.758, 1), (0.4, 0.983, 1)]], [[(0.868, 1.0, 0), (0.327, 0.871, 1), (0.568, 0.948, 0)], [(0.768, 0.78, 0)], [(0.505, 0.594, 0), (0.647, 0.947, 1)]], [[(0.816, 0.82, 0), (0.163, 0.208, 0), (0.947, 0.958, 0), (0.252, 0.418, 0), (0.385, 0.942, 1), (0.332, 0.563, 1), (0.226, 0.279, 0), (0.469, 0.546, 1), (0.627, 0.774, 0)], [(0.491, 0.851, 0)], [(0.27, 0.769, 1), (0.253, 0.487, 1)]]]
# 👋👋👋👋👋👋👋👋👋POPULATION BEFORE
# ►►►► in mutation function rule before mutation:  [[(0.266, 0.698, 0), (0.351, 0.553, 0), (0.115, 0.461, 1), (0.153, 0.727, 0)], [(0.036, 0.074, 1), (0.818, 0.889, 0), (0.583, 0.763, 0), (0.857, 0.983, 1)], [(0.12, 0.406, 0), (0.819, 0.941, 1), (0.482, 0.693, 1)]]
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.010336824483126339
# ►►►► In insertion mutation now ►►►►
# ►►►►rule before insert mutation:  [[(0.266, 0.698, 0), (0.351, 0.553, 0), (0.115, 0.461, 1), (0.153, 0.727, 0)], [(0.036, 0.074, 1), (0.818, 0.889, 0), (0.583, 0.763, 0), (0.857, 0.983, 1)], [(0.12, 0.406, 0), (0.819, 0.941, 1), (0.482, 0.693, 1)]]
# ►►►► ►►►► In insertion part of the mutation code ►►►► ►►►►
# ►►►►rule after insert mutation:  [[(0.266, 0.698, 0), (0.351, 0.553, 0), (0.115, 0.461, 1), (0.153, 0.727, 0), (0.346, 0.984, 1)], [(0.036, 0.074, 1), (0.818, 0.889, 0), (0.583, 0.763, 0), (0.857, 0.983, 1)], [(0.12, 0.406, 0), (0.819, 0.941, 1), (0.482, 0.693, 1)]]
# the bound that has been added is:  [(0.346, 0.984, 1)]
#
#
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.5700158345149097
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.41827743122296035
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.044268091822649125
# ►►►► In removing a tuple mutation now ►►►►
# ►►►► Rule before removing tuple mutation:  [[(0.266, 0.698, 0), (0.351, 0.553, 0), (0.115, 0.461, 1), (0.153, 0.727, 0), (0.346, 0.984, 1)], [(0.036, 0.074, 1), (0.818, 0.889, 0), (0.583, 0.763, 0), (0.857, 0.983, 1)], [(0.12, 0.406, 0), (0.819, 0.941, 1), (0.482, 0.693, 1)]]
# ►►►► Rule after removing tuple mutation:  [[(0.266, 0.698, 0), (0.351, 0.553, 0), (0.115, 0.461, 1), (0.346, 0.984, 1)], [(0.036, 0.074, 1), (0.818, 0.889, 0), (0.583, 0.763, 0), (0.857, 0.983, 1)], [(0.12, 0.406, 0), (0.819, 0.941, 1), (0.482, 0.693, 1)]]
# ►►►► rule removed is:  (0.153, 0.727, 0)
#
#
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.9580127008662818
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.2797879304316043
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.7826492048305816
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.2912871871268713
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.1103491938772827
# ►►►► In change a tuple from the rule by adding a small change mutation part ►►►►
# ►►►► the rule before mutation is:  [[(0.266, 0.698, 0), (0.351, 0.553, 0), (0.115, 0.461, 1), (0.346, 0.984, 1)], [(0.036, 0.074, 1), (0.818, 0.889, 0), (0.583, 0.763, 0), (0.857, 0.983, 1)], [(0.12, 0.406, 0), (0.819, 0.941, 1), (0.482, 0.693, 1)]]
# ►►►► delta introduced here:  -0.053156575702647674
# ►►►► tossing another coin for tuples' three values, lower limit, upper limit and the next state:  0.06159103361316731
# lower limit is going to be changed
#
#
# ►►►► in mutation function rule before mutation:  [[(0.723, 0.812, 0), (0.016, 0.982, 1), (0.313, 0.327, 0)], [(0.373, 0.878, 0), (0.329, 0.364, 0)], [(0.179, 0.24, 0), (0.787, 0.978, 1), (0.031, 0.755, 1)]]
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.25899223716678366
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.5487167056986844
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.9410087638043144
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.6573816464235159
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.15403605633538042
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.3498337988699364
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.2453262651227739
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.6817178947555232
# ►►►►►►►►No change
#
#
# ►►►► ending in mutation function rule after mutation [[(0.723, 0.812, 0), (0.016, 0.982, 1), (0.313, 0.327, 0)], [(0.373, 0.878, 0), (0.329, 0.364, 0)], [(0.179, 0.24, 0), (0.787, 0.978, 1), (0.031, 0.755, 1)]]
#
#  New loop of mutation starts here
# ►►►► in mutation function rule before mutation:  [[(0.4, 0.513, 1), (0.478, 0.637, 1)], [(0.935, 0.949, 1), (0.78, 0.927, 1)], [(0.464, 0.677, 0)]]
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.3008340607359077
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.1886503969236567
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.7838576461565718
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.09934143856674271
# ►►►► In change a tuple from the rule by adding a small change mutation part ►►►►
# ►►►► the rule before mutation is:  [[(0.4, 0.513, 1), (0.478, 0.637, 1)], [(0.935, 0.949, 1), (0.78, 0.927, 1)], [(0.464, 0.677, 0)]]
# ►►►► delta introduced here:  0.047836359710790394
# ►►►► tossing another coin for tuples' three values, lower limit, upper limit and the next state:  0.2663684487173218
# lower limit is going to be changed
#
#
# ►►►► in mutation function rule before mutation:  [[(0.921, 0.939, 1), (0.412, 0.853, 1)], [(0.73, 0.894, 1), (0.907, 0.939, 1), (0.518, 0.587, 1)], [(0.028, 0.829, 1), (0.681, 0.979, 1)]]
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.6930297559974462
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.7215063009768347
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.9841253837074796
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.3376846866917451
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.29739966583410404
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.8434032745428797
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.5363635785888289
# ►►►►►►►►No change
#
#
# ►►►► ending in mutation function rule after mutation [[(0.921, 0.939, 1), (0.412, 0.853, 1)], [(0.73, 0.894, 1), (0.907, 0.939, 1), (0.518, 0.587, 1)], [(0.028, 0.829, 1), (0.681, 0.979, 1)]]
#
#  New loop of mutation starts here
# ►►►► in mutation function rule before mutation:  [[(0.446, 0.462, 1), (0.352, 0.727, 0), (0.576, 0.924, 0), (0.326, 0.398, 0)], [(0.988, 0.997, 0), (0.186, 0.414, 0), (0.025, 0.906, 0)], [(0.097, 0.372, 1), (0.691, 0.928, 1), (0.146, 0.532, 1), (0.449, 0.615, 1)]]
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.9283297687329864
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.02861509563711262
# ►►►► In insertion mutation now ►►►►
# ►►►►rule before insert mutation:  [[(0.446, 0.462, 1), (0.352, 0.727, 0), (0.576, 0.924, 0), (0.326, 0.398, 0)], [(0.988, 0.997, 0), (0.186, 0.414, 0), (0.025, 0.906, 0)], [(0.097, 0.372, 1), (0.691, 0.928, 1), (0.146, 0.532, 1), (0.449, 0.615, 1)]]
# ►►►► ►►►► In insertion part of the mutation code ►►►► ►►►►
# ►►►►rule after insert mutation:  [[(0.446, 0.462, 1), (0.352, 0.727, 0), (0.576, 0.924, 0), (0.326, 0.398, 0), (0.774, 0.78, 0)], [(0.988, 0.997, 0), (0.186, 0.414, 0), (0.025, 0.906, 0)], [(0.097, 0.372, 1), (0.691, 0.928, 1), (0.146, 0.532, 1), (0.449, 0.615, 1)]]
# the bound that has been added is:  [(0.774, 0.78, 0)]
#
#
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.7922236343480787
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.7224859369551259
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.9005352241098931
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.7851104994354249
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.8776269636496898
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.2900112972149195
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.5419437503515511
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.8471468100024064
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.7689317404917132
# ►►►►►►►►No change
#
#
# ►►►► ending in mutation function rule after mutation [[(0.446, 0.462, 1), (0.352, 0.727, 0), (0.576, 0.924, 0), (0.326, 0.398, 0), (0.774, 0.78, 0)], [(0.988, 0.997, 0), (0.186, 0.414, 0), (0.025, 0.906, 0)], [(0.097, 0.372, 1), (0.691, 0.928, 1), (0.146, 0.532, 1), (0.449, 0.615, 1)]]
#
#  New loop of mutation starts here
# ►►►► in mutation function rule before mutation:  [[(0.861, 0.915, 0), (0.632, 0.71, 0), (0.355, 0.365, 1), (0.262, 0.788, 1), (0.593, 0.857, 1), (0.296, 0.42, 1)], [(0.677, 0.768, 1), (0.733, 0.941, 0), (0.388, 0.85, 1)], [(0.733, 0.739, 1), (0.302, 0.993, 0)]]
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.7791209267264914
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.19295296410808283
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.3968907379681593
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.7473702974752207
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.7628986302025492
# ►►►►►►►►No change
#
#
# ...
# ►►►►Value of tossed coin is:  0.45402615588105455
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.036477219795895244
# ►►►► In insertion mutation now ►►►►
# ►►►►rule before insert mutation:  [[(0.868, 1.0, 0), (0.568, 0.948, 0)], [(0.768, 0.78, 0)], [(0.505, 0.594, 0), (0.647, 0.947, 1)]]
# ►►►► ►►►► In insertion part of the mutation code ►►►► ►►►►
# ►►►►rule after insert mutation:  [[(0.868, 1.0, 0), (0.568, 0.948, 0)], [(0.768, 0.78, 0)], [(0.505, 0.594, 0), (0.647, 0.947, 1), (0.334, 0.949, 1)]]
# the bound that has been added is:  [(0.334, 0.949, 1)]
#
#
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.019083937254237737
# ►►►► In insertion mutation now ►►►►
# ►►►►rule before insert mutation:  [[(0.868, 1.0, 0), (0.568, 0.948, 0)], [(0.768, 0.78, 0)], [(0.505, 0.594, 0), (0.647, 0.947, 1), (0.334, 0.949, 1)]]
# ►►►► ►►►► In insertion part of the mutation code ►►►► ►►►►
# ►►►►rule after insert mutation:  [[(0.868, 1.0, 0), (0.568, 0.948, 0)], [(0.768, 0.78, 0)], [(0.505, 0.594, 0), (0.647, 0.947, 1), (0.334, 0.949, 1), (0.094, 0.517, 1)]]
# the bound that has been added is:  [(0.094, 0.517, 1)]
#
#
#
#
# ►►►► ending in mutation function rule after mutation [[(0.868, 1.0, 0), (0.568, 0.948, 0)], [(0.768, 0.78, 0)], [(0.505, 0.594, 0), (0.647, 0.947, 1), (0.334, 0.949, 1), (0.094, 0.517, 1)]]
#
#  New loop of mutation starts here
# ►►►► in mutation function rule before mutation:  [[(0.816, 0.82, 0), (0.163, 0.208, 0), (0.947, 0.958, 0), (0.252, 0.418, 0), (0.385, 0.942, 1), (0.226, 0.279, 0), (0.469, 0.546, 1), (0.021, 0.759, 1), (0.096, 0.257, 1), (0.374, 0.771, 1), (0.811, 0.996, 0)], [(0.491, 0.851, 0)], [(0.27, 0.769, 1), (0.253, 0.487, 1), (0.301, 0.337, 0)]]
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.5328224298226955
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.955155247081095
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.9122403767177009
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.6499158376090669
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.7452619254861345
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.8617381465308603
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.16742613270455842
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.23083922191163342
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.18192283366389328
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.7765322532012682
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.12159472494635493
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.34560786221490125
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.6659877605801335
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.3688465632457466
# ►►►►►►►►No change
#
#
# ►►►►Probabilities of insert 0.037037037037037035, remove 0.037037037037037035 and change 0.037037037037037035.
# ►►►►Tossed a coin to check what part of mutation needs to be performed, whether insertion / deletion / updation
# ►►►►Value of tossed coin is:  0.4209602122995344
# ►►►►►►►►No change
#
#
# ►►►► ending in mutation function rule after mutation [[(0.816, 0.82, 0), (0.163, 0.208, 0), (0.947, 0.958, 0), (0.252, 0.418, 0), (0.385, 0.942, 1), (0.226, 0.279, 0), (0.469, 0.546, 1), (0.021, 0.759, 1), (0.096, 0.257, 1), (0.374, 0.771, 1), (0.811, 0.996, 0)], [(0.491, 0.851, 0)], [(0.27, 0.769, 1), (0.253, 0.487, 1), (0.301, 0.337, 0)]]
#
#  New loop of mutation starts here
# 👋👋👋👋👋👋👋👋👋POPULATION AFTER
# [[[(0.266, 0.698, 0), (0.351, 0.553, 0), (0.115, 0.461, 1), (0.346, 0.984, 1), (0.114, 0.722, 1)], [(0.036, 0.074, 1), (0.818, 0.889, 0), (0.583, 0.763, 0), (0.857, 0.983, 1)], [(0.12, 0.406, 0), (0.819, 0.941, 1), (0.482, 0.693, 1)]], [[(0.723, 0.812, 0), (0.016, 0.982, 1), (0.313, 0.327, 0)], [(0.373, 0.878, 0), (0.67, 0.86, 0)], [(0.787, 0.978, 1), (0.031, 0.755, 1), (0.215, 0.252, 0), (0.756, 0.833, 1), (0.742, 0.831, 0)]], [[(0.478, 0.637, 1)], [(0.935, 0.949, 1), (0.78, 0.927, 1)], [(0.464, 0.677, 0)]], [[(0.921, 0.939, 1), (0.412, 0.853, 1)], [(0.73, 0.894, 1), (0.907, 0.939, 1), (0.518, 0.587, 1)], [(0.028, 0.829, 1), (0.681, 0.979, 1)]], [[(0.576, 0.924, 0), (0.326, 0.398, 0)], [(0.988, 0.997, 0), (0.186, 0.414, 0), (0.025, 0.906, 0), (0.39, 0.674, 1)], [(0.691, 0.928, 1), (0.146, 0.532, 1)]], [[(0.861, 0.915, 0), (0.632, 0.71, 0), (0.355, 0.365, 1), (0.593, 0.857, 1), (0.296, 0.42, 1)], [(0.677, 0.768, 1), (0.733, 0.941, 0), (0.672, 0.816, 1)], [(0.733, 0.739, 1), (0.155, 0.322, 1), (0.114, 0.25, 1)]], [[(0.899, 0.964, 1), (0.647, 0.677, 1)], [(0.125, 0.433, 0)], [(0.993, 0.994, 0), (0.759, 0.88, 1), (0.281, 0.759, 0), (0.444, 0.489, 1)]], [[(0.905, 0.982, 0), (0.078, 0.313, 1), (0.407, 0.572, 0), (0.264, 0.478, 0)], [(0.657, 0.859, 1)], [(0.549, 0.857, 0), (0.16, 0.418, 0), (0.09, 0.734, 0), (0.111, 0.758, 1), (0.4, 0.983, 1)]], [[(0.868, 1.0, 0), (0.568, 0.948, 0)], [(0.768, 0.78, 0)], [(0.505, 0.594, 0), (0.647, 0.947, 1)]], [[(0.816, 0.82, 0), (0.163, 0.208, 0), (0.947, 0.958, 0), (0.252, 0.418, 0), (0.385, 0.942, 1), (0.226, 0.279, 0), (0.469, 0.546, 1), (0.021, 0.759, 1), (0.096, 0.257, 1), (0.374, 0.771, 1), (0.811, 0.996, 0)], [(0.491, 0.851, 0)], [(0.27, 0.769, 1), (0.253, 0.487, 1), (0.301, 0.337, 0)]]]
# 👋👋👋👋👋👋👋👋👋POPULATION AFTER
#
#
# ▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲ Debugging in mutation finally in Genetic algorithm ▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲
# ▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲ Debugging in mutation finally in Genetic algorithm ▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲
# ▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲ Debugging in mutation finally in Genetic algorithm ▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲
# ►►►►Population before mutation List1  [[[(0.266, 0.698, 0), (0.351, 0.553, 0), (0.115, 0.461, 1), (0.346, 0.984, 1), (0.114, 0.722, 1)], [(0.036, 0.074, 1), (0.818, 0.889, 0), (0.583, 0.763, 0), (0.857, 0.983, 1)], [(0.12, 0.406, 0), (0.819, 0.941, 1), (0.482, 0.693, 1)]], [[(0.723, 0.812, 0), (0.016, 0.982, 1), (0.313, 0.327, 0)], [(0.373, 0.878, 0), (0.67, 0.86, 0)], [(0.787, 0.978, 1), (0.031, 0.755, 1), (0.215, 0.252, 0), (0.756, 0.833, 1), (0.742, 0.831, 0)]], [[(0.478, 0.637, 1)], [(0.935, 0.949, 1), (0.78, 0.927, 1)], [(0.464, 0.677, 0)]], [[(0.921, 0.939, 1), (0.412, 0.853, 1)], [(0.73, 0.894, 1), (0.907, 0.939, 1), (0.518, 0.587, 1)], [(0.028, 0.829, 1), (0.681, 0.979, 1)]], [[(0.576, 0.924, 0), (0.326, 0.398, 0)], [(0.988, 0.997, 0), (0.186, 0.414, 0), (0.025, 0.906, 0), (0.39, 0.674, 1)], [(0.691, 0.928, 1), (0.146, 0.532, 1)]], [[(0.861, 0.915, 0), (0.632, 0.71, 0), (0.355, 0.365, 1), (0.593, 0.857, 1), (0.296, 0.42, 1)], [(0.677, 0.768, 1), (0.733, 0.941, 0), (0.672, 0.816, 1)], [(0.733, 0.739, 1), (0.155, 0.322, 1), (0.114, 0.25, 1)]], [[(0.899, 0.964, 1), (0.647, 0.677, 1)], [(0.125, 0.433, 0)], [(0.993, 0.994, 0), (0.759, 0.88, 1), (0.281, 0.759, 0), (0.444, 0.489, 1)]], [[(0.905, 0.982, 0), (0.078, 0.313, 1), (0.407, 0.572, 0), (0.264, 0.478, 0)], [(0.657, 0.859, 1)], [(0.549, 0.857, 0), (0.16, 0.418, 0), (0.09, 0.734, 0), (0.111, 0.758, 1), (0.4, 0.983, 1)]], [[(0.868, 1.0, 0), (0.568, 0.948, 0)], [(0.768, 0.78, 0)], [(0.505, 0.594, 0), (0.647, 0.947, 1)]], [[(0.816, 0.82, 0), (0.163, 0.208, 0), (0.947, 0.958, 0), (0.252, 0.418, 0), (0.385, 0.942, 1), (0.226, 0.279, 0), (0.469, 0.546, 1), (0.021, 0.759, 1), (0.096, 0.257, 1), (0.374, 0.771, 1), (0.811, 0.996, 0)], [(0.491, 0.851, 0)], [(0.27, 0.769, 1), (0.253, 0.487, 1), (0.301, 0.337, 0)]]]
# ►►►►Population aafter mutation List2  [[[(0.266, 0.698, 0), (0.351, 0.553, 0), (0.115, 0.461, 1), (0.346, 0.984, 1), (0.114, 0.722, 1)], [(0.036, 0.074, 1), (0.818, 0.889, 0), (0.583, 0.763, 0), (0.857, 0.983, 1)], [(0.12, 0.406, 0), (0.819, 0.941, 1), (0.482, 0.693, 1)]], [[(0.723, 0.812, 0), (0.016, 0.982, 1), (0.313, 0.327, 0)], [(0.373, 0.878, 0), (0.67, 0.86, 0)], [(0.787, 0.978, 1), (0.031, 0.755, 1), (0.215, 0.252, 0), (0.756, 0.833, 1), (0.742, 0.831, 0)]], [[(0.478, 0.637, 1)], [(0.935, 0.949, 1), (0.78, 0.927, 1)], [(0.464, 0.677, 0)]], [[(0.921, 0.939, 1), (0.412, 0.853, 1)], [(0.907, 0.939, 1), (0.518, 0.587, 1)], [(0.028, 0.829, 1), (0.681, 0.979, 1)]], [[(0.576, 0.924, 0), (0.326, 0.398, 0)], [(0.988, 0.997, 0), (0.186, 0.414, 0), (0.025, 0.906, 0), (0.39, 0.674, 1)], [(0.691, 0.928, 1), (0.146, 0.532, 1)]], [[(0.861, 0.915, 0), (0.632, 0.71, 0), (0.355, 0.365, 1), (0.593, 0.857, 1), (0.296, 0.42, 1), (0.122, 0.367, 0)], [(0.677, 0.768, 1), (0.733, 0.941, 0), (0.672, 0.816, 1), (0.418, 0.581, 0)], [(0.733, 0.739, 1), (0.155, 0.322, 1), (0.114, 0.25, 1)]], [[(0.899, 0.964, 1), (0.647, 0.677, 1)], [(0.125, 0.433, 0)], [(0.993, 0.994, 0), (0.759, 0.88, 1), (0.281, 0.759, 0), (0.444, 0.489, 1)]], [[(0.905, 0.982, 0), (0.078, 0.313, 1), (0.407, 0.572, 0), (0.264, 0.478, 0)], [(0.657, 0.859, 1)], [(0.549, 0.857, 0), (0.16, 0.418, 0), (0.09, 0.734, 0), (0.111, 0.758, 1), (0.4, 0.983, 1)]], [[(0.868, 1.0, 0), (0.568, 0.948, 0)], [(0.768, 0.78, 0)], [(0.505, 0.594, 0), (0.647, 0.947, 1), (0.334, 0.949, 1), (0.094, 0.517, 1)]], [[(0.816, 0.82, 0), (0.163, 0.208, 0), (0.947, 0.958, 0), (0.252, 0.418, 0), (0.385, 0.942, 1), (0.226, 0.279, 0), (0.469, 0.546, 1), (0.021, 0.759, 1), (0.096, 0.257, 1), (0.374, 0.771, 1), (0.811, 0.996, 0)], [(0.491, 0.851, 0)], [(0.27, 0.769, 1), (0.253, 0.487, 1), (0.301, 0.337, 0)]]]
# ►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►
# Element 3,1 has changed from [(0.73, 0.894, 1), (0.907, 0.939, 1), (0.518, 0.587, 1)] to [(0.907, 0.939, 1), (0.518, 0.587, 1)]
# ►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►
# ►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►
# Element 5,0 has changed from [(0.861, 0.915, 0), (0.632, 0.71, 0), (0.355, 0.365, 1), (0.593, 0.857, 1), (0.296, 0.42, 1)] to [(0.861, 0.915, 0), (0.632, 0.71, 0), (0.355, 0.365, 1), (0.593, 0.857, 1), (0.296, 0.42, 1), (0.122, 0.367, 0)]
# ►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►
# ►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►
# Element 5,1 has changed from [(0.677, 0.768, 1), (0.733, 0.941, 0), (0.672, 0.816, 1)] to [(0.677, 0.768, 1), (0.733, 0.941, 0), (0.672, 0.816, 1), (0.418, 0.581, 0)]
# ►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►
# ►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►
# Element 8,2 has changed from [(0.505, 0.594, 0), (0.647, 0.947, 1)] to [(0.505, 0.594, 0), (0.647, 0.947, 1), (0.334, 0.949, 1), (0.094, 0.517, 1)]
# ►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►►
# Mutated Population:  [[[(0.266, 0.698, 0), (0.351, 0.553, 0), (0.115, 0.461, 1), (0.346, 0.984, 1), (0.114, 0.722, 1)], [(0.036, 0.074, 1), (0.818, 0.889, 0), (0.583, 0.763, 0), (0.857, 0.983, 1)], [(0.12, 0.406, 0), (0.819, 0.941, 1), (0.482, 0.693, 1)]], [[(0.723, 0.812, 0), (0.016, 0.982, 1), (0.313, 0.327, 0)], [(0.373, 0.878, 0), (0.67, 0.86, 0)], [(0.787, 0.978, 1), (0.031, 0.755, 1), (0.215, 0.252, 0), (0.756, 0.833, 1), (0.742, 0.831, 0)]], [[(0.478, 0.637, 1)], [(0.935, 0.949, 1), (0.78, 0.927, 1)], [(0.464, 0.677, 0)]], [[(0.921, 0.939, 1), (0.412, 0.853, 1)], [(0.907, 0.939, 1), (0.518, 0.587, 1)], [(0.028, 0.829, 1), (0.681, 0.979, 1)]], [[(0.576, 0.924, 0), (0.326, 0.398, 0)], [(0.988, 0.997, 0), (0.186, 0.414, 0), (0.025, 0.906, 0), (0.39, 0.674, 1)], [(0.691, 0.928, 1), (0.146, 0.532, 1)]], [[(0.861, 0.915, 0), (0.632, 0.71, 0), (0.355, 0.365, 1), (0.593, 0.857, 1), (0.296, 0.42, 1), (0.122, 0.367, 0)], [(0.677, 0.768, 1), (0.733, 0.941, 0), (0.672, 0.816, 1), (0.418, 0.581, 0)], [(0.733, 0.739, 1), (0.155, 0.322, 1), (0.114, 0.25, 1)]], [[(0.899, 0.964, 1), (0.647, 0.677, 1)], [(0.125, 0.433, 0)], [(0.993, 0.994, 0), (0.759, 0.88, 1), (0.281, 0.759, 0), (0.444, 0.489, 1)]], [[(0.905, 0.982, 0), (0.078, 0.313, 1), (0.407, 0.572, 0), (0.264, 0.478, 0)], [(0.657, 0.859, 1)], [(0.549, 0.857, 0), (0.16, 0.418, 0), (0.09, 0.734, 0), (0.111, 0.758, 1), (0.4, 0.983, 1)]], [[(0.868, 1.0, 0), (0.568, 0.948, 0)], [(0.768, 0.78, 0)], [(0.505, 0.594, 0), (0.647, 0.947, 1), (0.334, 0.949, 1), (0.094, 0.517, 1)]], [[(0.816, 0.82, 0), (0.163, 0.208, 0), (0.947, 0.958, 0), (0.252, 0.418, 0), (0.385, 0.942, 1), (0.226, 0.279, 0), (0.469, 0.546, 1), (0.021, 0.759, 1), (0.096, 0.257, 1), (0.374, 0.771, 1), (0.811, 0.996, 0)], [(0.491, 0.851, 0)], [(0.27, 0.769, 1), (0.253, 0.487, 1), (0.301, 0.337, 0)]]]
# --------------------------------------------------
#
#
# -------------------Preserving 1 Elite---------------------------
# Elite Chromosome:  [[(0.868, 1.0, 0), (0.568, 0.948, 0)], [(0.768, 0.78, 0)], [(0.505, 0.594, 0), (0.647, 0.947, 1)]]
# Elite Chromosome Fitness:  136407
# ----------------------------------------------------------------
# Best Chromosome from this Generation:  [[(0.868, 1.0, 0), (0.568, 0.948, 0)], [(0.768, 0.78, 0)], [(0.505, 0.594, 0), (0.647, 0.947, 1)]]
# Best Chromosome Fitness from this Generation:  136407
